# %% [markdown]
# # MNIST VERİ KÜMESİNİ KULLANARAK YAPAY SİNİR AĞLARI İLE RAKAM SINIFLANDIRÖA

# %% [markdown]
# ### Mnist verisini yükleme *italik metin* **kalın metin**

# %%
from keras.datasets import mnist
(train_images, train_labels),(test_images,test_labels)=mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
calisma_boyutu = train_images.shape
test_boyutu = test_images.shape
print ("çalışma boyutu = ", calisma_boyutu, " test boyutu", test_boyutu)
# Out:
# çalışma boyutu =  (60000, 28, 28)  test boyutu (10000, 28, 28)

# %% [markdown]
# ## Yapay Sinir Ağı Mimarisi

# %%
from keras import models
from keras import layers

# %%
network = models.Sequential()
network.add(layers.Dense(512,activation = 'relu', input_shape = (28*28,)))
network.add(layers.Dense(10,activation = 'softmax',))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ## YSA Modelinin Derlenmesi

# %%
network.compile(optimizer ='rmsprop',
                loss='categorical_crossentropy',
                metrics = ['accuracy'])

# %% [markdown]
# ## Girişlerin ve Etiketlerin Hazırlanması

# %%
train_images = train_images.reshape((60000,28*28))
train_images = train_images.astype('float32')/255

test_images = test_images.reshape((10000,28*28))
test_images = test_images.astype('float32')/255

# %%
from keras.utils import to_categorical
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %% [markdown]
# ## Yapay Sinir Ağı ( YSA) Modelinin Eğitilmesi

# %%
network.fit(train_images, train_labels, epochs=5, batch_size = 128)
# Out:
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.8734 - loss: 0.4466
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9666 - loss: 0.1161
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9776 - loss: 0.0732
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9856 - loss: 0.0506
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9886 - loss: 0.0373

# %%
test_loss, test_acc = network.evaluate(test_images,test_labels)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9757 - loss: 0.0811

# %%
print("test_loss: ",test_loss)
print("test_acc: ",test_acc)
# Out:
# test_loss:  0.0678916871547699
# test_acc:  0.979200005531311
