# %% [markdown]
# ## In lesson 5, started finally coding
#
# But he is coding in R, so I have to figure out how to code the same in Python, shouldn't be hard hopefully...

# %% [markdown]
# ## Video belongs years before. It seems they shared a library now that contains the same or similar data

# %%
# Install the package
# !pip install ucimlrepo

# %%
import pandas as pd
from ucimlrepo import fetch_ucirepo # Import the package

# %% [markdown]
# ## Visualize the data

# %%
germanCredit_raw =fetch_ucirepo(id=144) # Take the data
type(germanCredit_raw) # learn the type
germanCredit = germanCredit_raw.get("data") # Get what you need by parsing
germanCredit_features = germanCredit.get("features") # Get what you need once more to have cleaner data
germanCredit_targets = germanCredit.get("targets")

# %%
germanCredit_targets
# Out:
#      class
# 0        1
# 1        2
# 2        1
# 3        1
# 4        2
# ..     ...
# 995      1
# 996      1
# 997      1
# 998      2
# 999      1
#
# [1000 rows x 1 columns]

# %%
# From dict to dataframe
a = pd.DataFrame.from_dict(germanCredit_features) # First saved to a just because didn't want to change variable again till found the solutaion.
b = pd.DataFrame.from_dict(germanCredit_targets)

# %%
a
# Out:
#     Attribute1  Attribute2 Attribute3 Attribute4  Attribute5 Attribute6  \
# 0          A11           6        A34        A43        1169        A65
# 1          A12          48        A32        A43        5951        A61
# 2          A14          12        A34        A46        2096        A61
# 3          A11          42        A32        A42        7882        A61
# 4          A11          24        A33        A40        4870        A61
# ..         ...         ...        ...        ...         ...        ...
# 995        A14          12        A32        A42        1736        A61
# 996        A11          30        A32        A41        3857        A61
# 997        A14          12        A32        A43         804        A61
# 998        A11          45        A32        A43        1845        A61
# 999        A12          45        A34        A41        4576        A62
#
#     Attribute7  Attribute8 Attribute9 Attribute10  Attribute11 Attribute12  \
# ...

# %%
b
# Out:
#      class
# 0        1
# 1        2
# 2        1
# 3        1
# 4        2
# ..     ...
# 995      1
# 996      1
# 997      1
# 998      2
# 999      1
#
# [1000 rows x 1 columns]

# %% [markdown]
# ## Long efforts solved the problem.
#
# Finally, below is what in the first video was asked.

# %%
germanCredit = a.iloc[:,0:5]
germanCredit = pd.concat([germanCredit,b], axis=1)

# %% [markdown]
# ### Spoke too early it seems he was also asking for columns 21.
#
# In that column, integers of 1,2,3,4 exits but probably changed. Cause couldn't find
#
# For now just gonna watch all the videos as it is in R, try to understand what is being done. (2.02.25)
# **Note:** It seems 21.'st column there is rating, so ** I need to find the ratings...**

# %% [markdown]
# ### SOLVED THE PROBLEM IN THE SAME DAY BRAVO TO ME!!!

# %%
# Visualize
germanCredit
# Out:
#     Attribute1  Attribute2 Attribute3 Attribute4  Attribute5  class
# 0          A11           6        A34        A43        1169      1
# 1          A12          48        A32        A43        5951      2
# 2          A14          12        A34        A46        2096      1
# 3          A11          42        A32        A42        7882      1
# 4          A11          24        A33        A40        4870      2
# ..         ...         ...        ...        ...         ...    ...
# 995        A14          12        A32        A42        1736      1
# 996        A11          30        A32        A41        3857      1
# 997        A14          12        A32        A43         804      1
# 998        A11          45        A32        A43        1845      2
# 999        A12          45        A34        A41        4576      1
#
# [1000 rows x 6 columns]
