# %%
#@title Install required packages if needed:
# !pip install gym stable-baselines3 sb3-contrib --quiet
# !pip install 'shimmy>=2.0' --quiet

from sb3_contrib.ppo_recurrent import RecurrentPPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.callbacks import BaseCallback
from typing_extensions import final
import numpy as np
import pandas as pd
import gym
from gym import spaces
import matplotlib.pyplot as plt
import random
import datetime
import os
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# --------------------------
#@title 1. Data Loading & Preprocessing
# --------------------------

def resample_to_higher_tf(df, rule, col='close'):
    """
    Resample the 1-minute DataFrame to a higher timeframe by taking the last available close price.
    Then reindex the resulting series to the original timestamps (forward-filled).
    """
    df_copy = df.copy()
    df_copy['timestamp'] = pd.to_datetime(df_copy['timestamp'])  # Ensure timestamp is datetime
    df_copy.set_index('timestamp', inplace=True)  # Set timestamp as index

    # Resample and take the last value in each period.
    resampled = df_copy[col].resample(rule).last()

    # Reindex back to the original 1-minute timestamps using forward fill.
    resampled = resampled.reindex(df_copy.index, method='ffill')

    return resampled.reset_index(drop=True)  # Reset index to match the main DataFrame


# Load the 1m data
data_row = pd.read_csv("btc_1m_2012-2025-02.01-22.00.csv")
data=data_row
df_1m = data.rename(columns=str.lower)

# Derive higher timeframe closing prices:
df_1m['close_1m'] = df_1m['close']  # original 1m close
df_1m['close_1h'] = resample_to_higher_tf(df_1m, "60min", col='close')
df_1m['close_4h'] = resample_to_higher_tf(df_1m, "240min", col='close')

# For our environment, we need a DataFrame sorted by time.
df_1m.sort_values('timestamp', inplace=True)
df_1m.reset_index(drop=True, inplace=True)

# %%
df_1m = df_1m.iloc[:-1]

# %%
df_1m

# %%
# --------------------------
#@title 2. Custom Trading Environment
# --------------------------
class TradingEnv(gym.Env):
    """
    A custom trading environment for BTC/USD.

    Observation:
      A 3-dimensional vector:
        [close_1m, close_1h, close_4h]

    Actions:
      Discrete actions: 0: Hold, 1: Buy, 2: Sell.

    Reward:
      When the agent sells, the reward is the profit (or loss) realized.
      (For simplicity, we assume immediate execution and no transaction costs.)
    """
    metadata = {'render.modes': ['human']}

    def __init__(self, df):
        super(TradingEnv, self).__init__()
        self.df = df.copy()
        # Ensure there is enough data to compute higher timeframes.
        self.start_idx = 240  # 240 minutes for the 4h timeframe
        self.current_step = self.start_idx

        # Observation space: three continuous features.
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(3,), dtype=np.float32)
        # Action space: 0: Hold, 1: Buy, 2: Sell.
        self.action_space = spaces.Discrete(3)

        # Trading parameters
        self.initial_balance = 10000.0
        self.balance = self.initial_balance
        self.position = 0.0  # amount of BTC held
        self.entry_price = 0.0  # price when entering a position
        self.trades = []  # Store actions for analysis

    def reset(self):
        self.current_step = self.start_idx
        self.balance = self.initial_balance
        self.position = 0.0
        self.entry_price = 0.0
        self.trades= []
        return self._get_observation()

    def _get_observation(self):
        row = self.df.iloc[self.current_step]
        obs = np.array([row['close_1m'], row['close_1h'], row['close_4h']])
        return obs.astype(np.float32)

    def step(self, action):
        done = False
        reward = 0.0
        current_price = self.df.iloc[self.current_step]['close_1m']

        # Execute the chosen action:
        if action == 1:  # Buy
            if self.position == 0:  # only enter if no current position
                self.position = self.balance / current_price  # invest full balance
                self.entry_price = current_price
        elif action == 2:  # Sell
            if self.position > 0:  # only sell if in position
                profit = (current_price - self.entry_price) * self.position
                reward = profit
                self.balance += profit
                self.trades.append({
                    'entry_price': self.entry_price,
                    'exit_price': current_price,
                    'p/l': profit,
                    'step': self.current_step
                })
                print(f"Step {self.current_step}: SELL at {current_price:.2f} | P/L: {profit:.2f} | Balance: {self.balance:.2f}")
                self.position = 0.0
                self.entry_price = 0.0

        # Move to next timestep
        self.current_step += 1
        if self.current_step >= len(self.df) - 1:
            done = True
            # Liquidate any remaining position at the end.
            if self.position > 0:
                final_price = self.df.iloc[self.current_step]['close_1m']
                profit = (final_price - self.entry_price) * self.position
                reward += profit
                self.balance += profit
                self.trades.append({
                    'entry_price': self.entry_price,
                    'exit_price': final_price,
                    'p/l': profit,
                    'step': self.current_step
                })
                print(f"Step {self.current_step}: SELL at {exit_price:.2f} | P/L: {profit:.2f} | Balance: {self.balance:.2f}")
                self.position = 0.0

        next_obs = self._get_observation()
        info = {
            'balance': self.balance,
            'trades': self.trades,
            'current_step': self.current_step
        }
        return next_obs, reward, done, info

    def render(self, mode='human'):
        print(f"Step: {self.current_step}, Balance: {self.balance:.2f}, Position: {self.position:.4f}, Price: {self.df.iloc[self.current_step]['close_1m']:.2f}")

# %%
# --------------------------
#@title 3. PPO with LSTM (RecurrentPPO) and Reward Logging
# --------------------------

class RewardLoggingCallback(BaseCallback):
    """
    Custom callback for logging rewards at the end of each episode.
    """
    def __init__(self, verbose=0):
        super(RewardLoggingCallback, self).__init__(verbose)
        self.episode_rewards = []

    def _on_step(self) -> bool:
        # Check if done flag is present in infos.
        for info in self.locals.get("infos", []):
            if "episode" in info.keys():
                self.episode_rewards.append(info["episode"]["r"])
        return True

# Wrap our custom environment in a DummyVecEnv:
env = DummyVecEnv([lambda: TradingEnv(df_1m)])

# Create the RecurrentPPO agent using an LSTM-based policy.
model = RecurrentPPO("MlpLstmPolicy", env, verbose=1)

# Create our reward logging callback.
reward_callback = RewardLoggingCallback()

# Train the agent for a specified number of timesteps.
total_timesteps = 100_00
#model.learn(total_timesteps=total_timesteps, callback=reward_callback)
#model.save("ppo_trading_agent_lstm_1m")

print("Training complete. Model saved as 'ppo_trading_agent_lstm_1m'.")
# Out:
# Using cpu device
# Training complete. Model saved as 'ppo_trading_agent_lstm_1m'.

# %% [markdown]
# ## Different models

# %% [markdown]
# ### Model_2
#
# Learning_rate = 0.01
#
# **Results:**
#
# iterations = 10112
#
# f_balance =  10300

# %%
model_2 = RecurrentPPO("MlpLstmPolicy", env, learning_rate=0.01, verbose=1)
model_2.learn(total_timesteps=total_timesteps, callback=reward_callback)

# %% [markdown]
# ### model_3
#
# Learning_rate = 0.001
#
# **Results:**
#
# iterations = 10112
#
# f_balance = 12043.86

# %%
model_3 = RecurrentPPO("MlpLstmPolicy", env, learning_rate=0.001, verbose=1)
model_3.learn(total_timesteps=total_timesteps, callback=reward_callback)

# %% [markdown]
# ### model_3_1
#
# Learning_rate = 0.001
#
# **Results:**
#
# iterations = 20112
#
# f_balance = 12043.86

# %%
total_timesteps=30112
model_3_1 = RecurrentPPO("MlpLstmPolicy", env, learning_rate=0.001, verbose=1)
model_3_1.learn(total_timesteps=total_timesteps, callback=reward_callback)
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.785        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 110           |
# |    n_updates            | 630           |
# |    policy_gradient_loss | -3.27e-05     |
# |    value_loss           | 220           |
# -------------------------------------------
# Step 8448: SELL at 68611.00 | P/L: -21.69 | Balance: 9922.12
# Step 8497: SELL at 68719.00 | P/L: 15.47 | Balance: 9937.59
# Step 8505: SELL at 68800.00 | P/L: 7.08 | Balance: 9944.68
# Step 8518: SELL at 68840.00 | P/L: 3.61 | Balance: 9948.29
# Step 8535: SELL at 68811.00 | P/L: -2.02 | Balance: 9946.27
# Step 8547: SELL at 68805.00 | P/L: -13.57 | Balance: 9932.70
# Step 8554: SELL at 68777.00 | P/L: -4.04 | Balance: 9928.65
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 79          |
# |    iterations           | 65          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 8320        |
# | train/                  |             |
# |    approx_kl            | 0.000561174 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.78       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.001       |
# |    loss                 | 14.9        |
# |    n_updates            | 640         |
# |    policy_gradient_loss | -0.0016     |
# |    value_loss           | 30.9        |
# -----------------------------------------
# Step 8575: SELL at 68717.00 | P/L: -10.39 | Balance: 9918.26
# Step 8629: SELL at 68771.00 | P/L: 3.61 | Balance: 9921.87
# Step 8638: SELL at 68677.00 | P/L: -7.80 | Balance: 9914.07
# Step 8652: SELL at 68706.00 | P/L: 4.91 | Balance: 9918.98
# Step 8673: SELL at 68788.00 | P/L: 5.92 | Balance: 9924.90
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 79           |
# |    iterations           | 66           |
# |    time_elapsed         | 106          |
# |    total_timesteps      | 8448         |
# | train/                  |              |
# |    approx_kl            | 0.0004403675 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.751       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.001        |
# |    loss                 | 37.1         |
# |    n_updates            | 650          |
# |    policy_gradient_loss | -0.000825    |
# |    value_loss           | 74.9         |
# ------------------------------------------
# Step 8703: SELL at 69254.00 | P/L: 71.45 | Balance: 9996.35
# Step 8746: SELL at 69698.00 | P/L: 42.20 | Balance: 10038.55
# Step 8783: SELL at 69691.00 | P/L: -11.08 | Balance: 10027.47
# Step 8797: SELL at 69533.00 | P/L: -28.04 | Balance: 9999.43
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 67          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 8576        |
# | train/                  |             |
# |    approx_kl            | 0.009169117 |
# |    clip_fraction        | 0.0289      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.774      |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.001       |
# |    loss                 | 6.17        |
# |    n_updates            | 660         |
# |    policy_gradient_loss | -0.00263    |
# |    value_loss           | 12.6        |
# -----------------------------------------
# Step 8822: SELL at 69937.00 | P/L: 54.48 | Balance: 10053.91
# Step 8879: SELL at 70350.00 | P/L: 57.35 | Balance: 10111.26
# Step 8885: SELL at 70262.00 | P/L: -8.63 | Balance: 10102.63
# Step 8924: SELL at 70023.00 | P/L: -23.89 | Balance: 10078.74
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 78           |
# |    iterations           | 68           |
# |    time_elapsed         | 110          |
# |    total_timesteps      | 8704         |
# | train/                  |              |
# |    approx_kl            | 8.622371e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.795       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.001        |
# |    loss                 | 249          |
# |    n_updates            | 670          |
# |    policy_gradient_loss | 0.000645     |
# |    value_loss           | 498          |
# ------------------------------------------
# Step 8963: SELL at 70136.00 | P/L: 15.69 | Balance: 10094.43
# Step 8998: SELL at 69948.00 | P/L: -19.73 | Balance: 10074.69
# Step 9037: SELL at 68830.00 | P/L: -157.06 | Balance: 9917.64
# Step 9040: SELL at 69121.00 | P/L: -0.29 | Balance: 9917.35
# Step 9067: SELL at 69431.00 | P/L: 30.37 | Balance: 9947.72
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 78            |
# |    iterations           | 69            |
# |    time_elapsed         | 111           |
# |    total_timesteps      | 8832          |
# | train/                  |               |
# |    approx_kl            | 6.0927123e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.793        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 160           |
# |    n_updates            | 680           |
# |    policy_gradient_loss | -0.000112     |
# |    value_loss           | 323           |
# -------------------------------------------
# Step 9082: SELL at 69516.00 | P/L: 15.05 | Balance: 9962.77
# Step 9105: SELL at 69391.00 | P/L: -13.91 | Balance: 9948.86
# Step 9115: SELL at 69383.00 | P/L: 6.17 | Balance: 9955.03
# Step 9118: SELL at 69527.00 | P/L: 12.76 | Balance: 9967.79
# Step 9143: SELL at 69502.00 | P/L: -6.02 | Balance: 9961.77
# Step 9158: SELL at 69086.00 | P/L: -40.78 | Balance: 9920.99
# Step 9176: SELL at 69036.00 | P/L: -10.34 | Balance: 9910.65
# Step 9190: SELL at 69387.00 | P/L: 52.55 | Balance: 9963.21
# Step 9194: SELL at 69358.00 | P/L: -8.90 | Balance: 9954.31
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 78           |
# |    iterations           | 70           |
# |    time_elapsed         | 114          |
# |    total_timesteps      | 8960         |
# | train/                  |              |
# |    approx_kl            | 1.864601e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.795       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.001        |
# |    loss                 | 868          |
# |    n_updates            | 690          |
# |    policy_gradient_loss | 0.000109     |
# |    value_loss           | 1.74e+03     |
# ------------------------------------------
# Step 9206: SELL at 69358.00 | P/L: 0.14 | Balance: 9954.45
# Step 9225: SELL at 69576.00 | P/L: 36.19 | Balance: 9990.64
# Step 9274: SELL at 69408.00 | P/L: -17.67 | Balance: 9972.96
# Step 9284: SELL at 74877.00 | P/L: 792.95 | Balance: 10765.92
# Step 9293: SELL at 74863.00 | P/L: 5.76 | Balance: 10771.67
# Step 9321: SELL at 74815.00 | P/L: -6.19 | Balance: 10765.49
# Step 9325: SELL at 74943.00 | P/L: 18.71 | Balance: 10784.19
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 77           |
# |    iterations           | 71           |
# |    time_elapsed         | 117          |
# |    total_timesteps      | 9088         |
# | train/                  |              |
# |    approx_kl            | 0.0032800194 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.784       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.001        |
# |    loss                 | 128          |
# |    n_updates            | 700          |
# |    policy_gradient_loss | -0.00202     |
# |    value_loss           | 256          |
# ------------------------------------------
# Step 9338: SELL at 75162.00 | P/L: 13.79 | Balance: 10797.99
# Step 9428: SELL at 74980.00 | P/L: -19.84 | Balance: 10778.15
# Step 9437: SELL at 74972.00 | P/L: 2.30 | Balance: 10780.45
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 77           |
# |    iterations           | 72           |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 9216         |
# | train/                  |              |
# |    approx_kl            | 0.0050989697 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.729       |
# |    explained_variance   | 2.98e-07     |
# |    learning_rate        | 0.001        |
# |    loss                 | 2.1e+04      |
# |    n_updates            | 710          |
# |    policy_gradient_loss | 0.00247      |
# |    value_loss           | 4.2e+04      |
# ------------------------------------------
# Step 9518: SELL at 74936.00 | P/L: -3.88 | Balance: 10776.57
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 77           |
# |    iterations           | 73           |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 9344         |
# | train/                  |              |
# |    approx_kl            | 0.0011261604 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.693       |
# |    explained_variance   | -2.38e-07    |
# |    learning_rate        | 0.001        |
# |    loss                 | 17.3         |
# |    n_updates            | 720          |
# |    policy_gradient_loss | -0.00103     |
# |    value_loss           | 35           |
# ------------------------------------------
# Step 9597: SELL at 74986.00 | P/L: 5.32 | Balance: 10781.89
# Step 9599: SELL at 74986.00 | P/L: -4.17 | Balance: 10777.72
# Step 9631: SELL at 74987.00 | P/L: -5.03 | Balance: 10772.69
# Step 9687: SELL at 74783.00 | P/L: -29.02 | Balance: 10743.67
# Step 9691: SELL at 74880.00 | P/L: 6.03 | Balance: 10749.70
# Step 9708: SELL at 74902.00 | P/L: 10.77 | Balance: 10760.47
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 77            |
# |    iterations           | 74            |
# |    time_elapsed         | 122           |
# |    total_timesteps      | 9472          |
# | train/                  |               |
# |    approx_kl            | 0.00025822222 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.672        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 0.672         |
# |    n_updates            | 730           |
# |    policy_gradient_loss | -0.00176      |
# |    value_loss           | 1.74          |
# -------------------------------------------
# Step 9738: SELL at 74871.00 | P/L: -11.77 | Balance: 10748.70
# Step 9757: SELL at 75487.00 | P/L: 105.11 | Balance: 10853.81
# Step 9825: SELL at 75744.00 | P/L: 54.44 | Balance: 10908.25
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 77           |
# |    iterations           | 75           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 9600         |
# | train/                  |              |
# |    approx_kl            | 0.0034645302 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.686       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.001        |
# |    loss                 | 21.7         |
# |    n_updates            | 740          |
# |    policy_gradient_loss | -0.00236     |
# |    value_loss           | 44.8         |
# ------------------------------------------
# Step 9873: SELL at 76213.00 | P/L: 71.60 | Balance: 10979.85
# Step 9887: SELL at 76370.00 | P/L: 21.61 | Balance: 11001.46
# Step 9933: SELL at 76125.00 | P/L: -34.58 | Balance: 10966.88
# Step 9965: SELL at 76576.00 | P/L: 48.62 | Balance: 11015.50
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 77           |
# |    iterations           | 76           |
# |    time_elapsed         | 125          |
# |    total_timesteps      | 9728         |
# | train/                  |              |
# |    approx_kl            | 0.0010556541 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.715       |
# |    explained_variance   | 6.02e-06     |
# |    learning_rate        | 0.001        |
# |    loss                 | 451          |
# |    n_updates            | 750          |
# |    policy_gradient_loss | -0.000443    |
# |    value_loss           | 902          |
# ------------------------------------------
# Step 10009: SELL at 76331.00 | P/L: -46.13 | Balance: 10969.37
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 77            |
# |    iterations           | 77            |
# |    time_elapsed         | 127           |
# |    total_timesteps      | 9856          |
# | train/                  |               |
# |    approx_kl            | 0.00021846686 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.731        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 319           |
# |    n_updates            | 760           |
# |    policy_gradient_loss | 3.25e-05      |
# |    value_loss           | 644           |
# -------------------------------------------
# Step 10116: SELL at 76354.00 | P/L: -8.61 | Balance: 10960.76
# Step 10167: SELL at 75821.00 | P/L: -82.07 | Balance: 10878.69
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 76            |
# |    iterations           | 78            |
# |    time_elapsed         | 130           |
# |    total_timesteps      | 9984          |
# | train/                  |               |
# |    approx_kl            | 4.7972426e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.736        |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.001         |
# |    loss                 | 75.2          |
# |    n_updates            | 770           |
# |    policy_gradient_loss | -0.00018      |
# |    value_loss           | 151           |
# -------------------------------------------
# Step 10242: SELL at 75955.00 | P/L: 21.96 | Balance: 10900.65
# Step 10248: SELL at 75917.00 | P/L: -4.74 | Balance: 10895.91
# Step 10335: SELL at 76591.00 | P/L: 96.88 | Balance: 10992.79
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 75           |
# |    iterations           | 79           |
# |    time_elapsed         | 133          |
# |    total_timesteps      | 10112        |
# | train/                  |              |
# |    approx_kl            | 2.099201e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.729       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.001        |
# |    loss                 | 235          |
# |    n_updates            | 780          |
# |    policy_gradient_loss | -0.00065     |
# |    value_loss           | 474          |
# ------------------------------------------
# Step 10369: SELL at 76607.00 | P/L: 1.58 | Balance: 10994.37
# Step 10396: SELL at 76620.00 | P/L: 1.72 | Balance: 10996.09
# Step 10470: SELL at 76508.00 | P/L: -9.76 | Balance: 10986.33
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 75            |
# |    iterations           | 80            |
# |    time_elapsed         | 134           |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 2.4558045e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.725        |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.001         |
# |    loss                 | 324           |
# |    n_updates            | 790           |
# |    policy_gradient_loss | 3.95e-05      |
# |    value_loss           | 648           |
# -------------------------------------------
# Step 10491: SELL at 76526.00 | P/L: 4.02 | Balance: 10990.35
# Step 10510: SELL at 76475.00 | P/L: -7.32 | Balance: 10983.02
# Step 10513: SELL at 76480.00 | P/L: 0.86 | Balance: 10983.88
# Step 10539: SELL at 76439.00 | P/L: -5.74 | Balance: 10978.14
# Step 10556: SELL at 76526.00 | P/L: 12.06 | Balance: 10990.20
# Step 10579: SELL at 76461.00 | P/L: -9.33 | Balance: 10980.87
# Step 10606: SELL at 76377.00 | P/L: -14.21 | Balance: 10966.65
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 75           |
# |    iterations           | 81           |
# |    time_elapsed         | 136          |
# |    total_timesteps      | 10368        |
# | train/                  |              |
# |    approx_kl            | 0.0030270605 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.705       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.001        |
# |    loss                 | 3.69         |
# |    n_updates            | 800          |
# |    policy_gradient_loss | -0.00329     |
# |    value_loss           | 7.6          |
# ------------------------------------------
# Step 10667: SELL at 76389.00 | P/L: 2.58 | Balance: 10969.24
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 75           |
# |    iterations           | 82           |
# |    time_elapsed         | 138          |
# |    total_timesteps      | 10496        |
# | train/                  |              |
# |    approx_kl            | 0.0040022884 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.644       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.001        |
# |    loss                 | 15.2         |
# |    n_updates            | 810          |
# |    policy_gradient_loss | -0.00195     |
# |    value_loss           | 31.7         |
# ------------------------------------------
# Step 10746: SELL at 76335.00 | P/L: -12.92 | Balance: 10956.32
# Step 10751: SELL at 76350.00 | P/L: 1.29 | Balance: 10957.61
# Step 10788: SELL at 76351.00 | P/L: -0.29 | Balance: 10957.32
# Step 10818: SELL at 76251.00 | P/L: -16.21 | Balance: 10941.11
# Step 10863: SELL at 76061.00 | P/L: -15.51 | Balance: 10925.60
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 75        |
# |    iterations           | 83        |
# |    time_elapsed         | 140       |
# |    total_timesteps      | 10624     |
# | train/                  |           |
# |    approx_kl            | 0.0446029 |
# |    clip_fraction        | 0.17      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.751    |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 0.16      |
# |    n_updates            | 820       |
# |    policy_gradient_loss | -0.00758  |
# |    value_loss           | 0.334     |
# ---------------------------------------
# Step 10873: SELL at 75904.00 | P/L: -17.10 | Balance: 10908.50
# Step 10890: SELL at 76014.00 | P/L: 20.85 | Balance: 10929.34
# Step 10895: SELL at 76010.00 | P/L: 1.58 | Balance: 10930.93
# Step 10909: SELL at 76152.00 | P/L: 19.41 | Balance: 10950.34
# Step 10938: SELL at 76311.00 | P/L: 21.71 | Balance: 10972.05
# Step 10950: SELL at 76347.00 | P/L: 3.45 | Balance: 10975.50
# Step 10959: SELL at 76362.00 | P/L: 2.01 | Balance: 10977.51
# Step 10976: SELL at 76393.00 | P/L: 2.59 | Balance: 10980.10
# Step 10986: SELL at 76585.00 | P/L: 27.60 | Balance: 11007.70
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 75         |
# |    iterations           | 84         |
# |    time_elapsed         | 142        |
# |    total_timesteps      | 10752      |
# | train/                  |            |
# |    approx_kl            | 0.01483986 |
# |    clip_fraction        | 0.1        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.829     |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.001      |
# |    loss                 | 22.7       |
# |    n_updates            | 830        |
# |    policy_gradient_loss | 0.00391    |
# |    value_loss           | 46.5       |
# ----------------------------------------
# Step 10997: SELL at 76580.00 | P/L: 2.73 | Balance: 11010.43
# Step 11005: SELL at 76451.00 | P/L: -15.82 | Balance: 10994.61
# Step 11018: SELL at 76217.00 | P/L: -26.34 | Balance: 10968.27
# Step 11020: SELL at 76191.00 | P/L: -3.02 | Balance: 10965.25
# Step 11058: SELL at 76318.00 | P/L: 16.69 | Balance: 10981.94
# Step 11072: SELL at 76361.00 | P/L: 11.23 | Balance: 10993.17
# Step 11086: SELL at 76332.00 | P/L: -3.60 | Balance: 10989.57
# Step 11107: SELL at 76289.00 | P/L: -2.74 | Balance: 10986.84
# Step 11113: SELL at 76270.00 | P/L: -2.88 | Balance: 10983.96
# Step 11119: SELL at 76335.00 | P/L: 6.19 | Balance: 10990.15
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 75           |
# |    iterations           | 85           |
# |    time_elapsed         | 144          |
# |    total_timesteps      | 10880        |
# | train/                  |              |
# |    approx_kl            | 0.0014828518 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.805       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.001        |
# |    loss                 | 92.8         |
# |    n_updates            | 840          |
# |    policy_gradient_loss | -0.00414     |
# |    value_loss           | 187          |
# ------------------------------------------
# Step 11140: SELL at 76382.00 | P/L: -2.45 | Balance: 10987.70
# Step 11154: SELL at 76421.00 | P/L: 4.75 | Balance: 10992.45
# Step 11163: SELL at 76486.00 | P/L: -0.57 | Balance: 10991.87
# Step 11175: SELL at 76424.00 | P/L: 0.86 | Balance: 10992.74
# Step 11205: SELL at 76611.00 | P/L: 22.29 | Balance: 11015.02
# Step 11208: SELL at 76505.00 | P/L: -16.53 | Balance: 10998.49
# Step 11227: SELL at 76710.00 | P/L: 38.27 | Balance: 11036.76
# Step 11247: SELL at 76849.00 | P/L: 16.25 | Balance: 11053.01
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 74            |
# |    iterations           | 86            |
# |    time_elapsed         | 146           |
# |    total_timesteps      | 11008         |
# | train/                  |               |
# |    approx_kl            | 4.4026878e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.793        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 58.9          |
# |    n_updates            | 850           |
# |    policy_gradient_loss | 0.000188      |
# |    value_loss           | 118           |
# -------------------------------------------
# Step 11268: SELL at 76847.00 | P/L: 1.29 | Balance: 11054.31
# Step 11270: SELL at 76829.00 | P/L: -3.16 | Balance: 11051.14
# Step 11300: SELL at 80976.00 | P/L: 614.88 | Balance: 11666.02
# Step 11302: SELL at 81026.00 | P/L: 3.74 | Balance: 11669.77
# Step 11306: SELL at 81191.00 | P/L: 0.29 | Balance: 11670.06
# Step 11316: SELL at 81278.00 | P/L: 16.82 | Balance: 11686.88
# Step 11323: SELL at 81308.00 | P/L: 8.49 | Balance: 11695.37
# Step 11326: SELL at 81252.00 | P/L: -8.49 | Balance: 11686.88
# Step 11332: SELL at 81281.00 | P/L: -11.78 | Balance: 11675.10
# Step 11339: SELL at 81230.00 | P/L: -6.46 | Balance: 11668.64
# Step 11341: SELL at 81207.00 | P/L: -2.15 | Balance: 11666.48
# Step 11360: SELL at 81270.00 | P/L: 12.50 | Balance: 11678.98
# Step 11374: SELL at 81433.00 | P/L: 22.27 | Balance: 11701.26
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 74            |
# |    iterations           | 87            |
# |    time_elapsed         | 149           |
# |    total_timesteps      | 11136         |
# | train/                  |               |
# |    approx_kl            | 0.00014213286 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.785        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 76.3          |
# |    n_updates            | 860           |
# |    policy_gradient_loss | 4.89e-05      |
# |    value_loss           | 154           |
# -------------------------------------------
# Step 11387: SELL at 81435.00 | P/L: 15.54 | Balance: 11716.80
# Step 11398: SELL at 81496.00 | P/L: 7.34 | Balance: 11724.13
# Step 11406: SELL at 81424.00 | P/L: -8.92 | Balance: 11715.21
# Step 11416: SELL at 81545.00 | P/L: 16.11 | Balance: 11731.32
# Step 11423: SELL at 81563.00 | P/L: -12.36 | Balance: 11718.97
# Step 11434: SELL at 81776.00 | P/L: 38.39 | Balance: 11757.36
# Step 11454: SELL at 82219.00 | P/L: 55.60 | Balance: 11812.96
# Step 11470: SELL at 82045.00 | P/L: -21.99 | Balance: 11790.97
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 74           |
# |    iterations           | 88           |
# |    time_elapsed         | 151          |
# |    total_timesteps      | 11264        |
# | train/                  |              |
# |    approx_kl            | 5.531218e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.776       |
# |    explained_variance   | 3.22e-06     |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.31e+04     |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -0.00041     |
# |    value_loss           | 2.62e+04     |
# ------------------------------------------
# Step 11524: SELL at 82192.00 | P/L: 24.58 | Balance: 11815.55
# Step 11534: SELL at 82269.00 | P/L: 7.19 | Balance: 11822.74
# Step 11537: SELL at 82198.00 | P/L: 0.29 | Balance: 11823.03
# Step 11543: SELL at 82087.00 | P/L: -1.58 | Balance: 11821.44
# Step 11570: SELL at 82339.00 | P/L: 30.08 | Balance: 11851.52
# Step 11576: SELL at 82250.00 | P/L: -15.83 | Balance: 11835.70
# Step 11585: SELL at 82102.00 | P/L: -11.95 | Balance: 11823.74
# Step 11608: SELL at 82328.00 | P/L: 36.88 | Balance: 11860.62
# Step 11610: SELL at 82332.00 | P/L: 7.93 | Balance: 11868.55
# Step 11618: SELL at 82251.00 | P/L: -17.15 | Balance: 11851.40
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 74           |
# |    iterations           | 89           |
# |    time_elapsed         | 152          |
# |    total_timesteps      | 11392        |
# | train/                  |              |
# |    approx_kl            | 4.146248e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.772       |
# |    explained_variance   | 4.2e-05      |
# |    learning_rate        | 0.001        |
# |    loss                 | 176          |
# |    n_updates            | 880          |
# |    policy_gradient_loss | -9.36e-05    |
# |    value_loss           | 358          |
# ------------------------------------------
# Step 11642: SELL at 81842.00 | P/L: -64.81 | Balance: 11786.60
# Step 11645: SELL at 81848.00 | P/L: -13.95 | Balance: 11772.65
# Step 11686: SELL at 82180.00 | P/L: 26.27 | Balance: 11798.92
# Step 11691: SELL at 81906.00 | P/L: -38.05 | Balance: 11760.87
# Step 11693: SELL at 81816.00 | P/L: -3.31 | Balance: 11757.56
# Step 11703: SELL at 81689.00 | P/L: -29.58 | Balance: 11727.99
# Step 11708: SELL at 81824.00 | P/L: 16.51 | Balance: 11744.49
# Step 11712: SELL at 82496.00 | P/L: 116.89 | Balance: 11861.39
# Step 11714: SELL at 82317.00 | P/L: -4.47 | Balance: 11856.92
# Step 11718: SELL at 82465.00 | P/L: -9.63 | Balance: 11847.30
# Step 11721: SELL at 82488.00 | P/L: -5.60 | Balance: 11841.70
# Step 11727: SELL at 82320.00 | P/L: 39.40 | Balance: 11881.10
# Step 11737: SELL at 82575.00 | P/L: 30.58 | Balance: 11911.68
# Step 11741: SELL at 82665.00 | P/L: 5.77 | Balance: 11917.45
# Step 11744: SELL at 82863.00 | P/L: 16.71 | Balance: 11934.16
# Step 11751: SELL at 82921.00 | P/L: 25.10 | Balance: 11959.25
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 74            |
# |    iterations           | 90            |
# |    time_elapsed         | 154           |
# |    total_timesteps      | 11520         |
# | train/                  |               |
# |    approx_kl            | 8.7038614e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.77         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 82.2          |
# |    n_updates            | 890           |
# |    policy_gradient_loss | -0.000575     |
# |    value_loss           | 168           |
# -------------------------------------------
# Step 11763: SELL at 83551.00 | P/L: 72.00 | Balance: 12031.25
# Step 11767: SELL at 83689.00 | P/L: 18.43 | Balance: 12049.68
# Step 11790: SELL at 84040.00 | P/L: 29.75 | Balance: 12079.43
# Step 11798: SELL at 84200.00 | P/L: 33.66 | Balance: 12113.10
# Step 11808: SELL at 84723.00 | P/L: 71.19 | Balance: 12184.28
# Step 11813: SELL at 84899.00 | P/L: 27.62 | Balance: 12211.90
# Step 11820: SELL at 84867.00 | P/L: 15.13 | Balance: 12227.03
# Step 11848: SELL at 84231.00 | P/L: -96.49 | Balance: 12130.54
# Step 11855: SELL at 84088.00 | P/L: -26.34 | Balance: 12104.20
# Step 11869: SELL at 84781.00 | P/L: 88.59 | Balance: 12192.79
# Step 11872: SELL at 84799.00 | P/L: -2.30 | Balance: 12190.49
# Step 11874: SELL at 84683.00 | P/L: -15.53 | Balance: 12174.96
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 74           |
# |    iterations           | 91           |
# |    time_elapsed         | 156          |
# |    total_timesteps      | 11648        |
# | train/                  |              |
# |    approx_kl            | 9.386288e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.758       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.001        |
# |    loss                 | 897          |
# |    n_updates            | 900          |
# |    policy_gradient_loss | -9.05e-05    |
# |    value_loss           | 1.8e+03      |
# ------------------------------------------
# Step 11896: SELL at 84833.00 | P/L: 15.09 | Balance: 12190.05
# Step 11898: SELL at 84939.00 | P/L: 12.93 | Balance: 12202.98
# Step 11904: SELL at 84909.00 | P/L: 1.01 | Balance: 12203.98
# Step 11918: SELL at 84744.00 | P/L: -31.46 | Balance: 12172.53
# Step 11958: SELL at 85210.00 | P/L: 85.31 | Balance: 12257.83
# Step 11966: SELL at 85263.00 | P/L: 9.06 | Balance: 12266.90
# Step 11974: SELL at 85720.00 | P/L: 28.11 | Balance: 12295.01
# Step 11980: SELL at 85885.00 | P/L: 26.68 | Balance: 12321.69
# Step 11989: SELL at 86062.00 | P/L: 54.94 | Balance: 12376.63
# Step 11991: SELL at 85798.00 | P/L: -32.37 | Balance: 12344.26
# Step 11997: SELL at 86080.00 | P/L: 35.09 | Balance: 12379.35
# Step 12004: SELL at 86006.00 | P/L: -33.73 | Balance: 12345.61
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 74            |
# |    iterations           | 92            |
# |    time_elapsed         | 159           |
# |    total_timesteps      | 11776         |
# | train/                  |               |
# |    approx_kl            | 5.1913783e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.757        |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.14e+03      |
# |    n_updates            | 910           |
# |    policy_gradient_loss | -0.000503     |
# |    value_loss           | 2.28e+03      |
# -------------------------------------------
# Step 12026: SELL at 86566.00 | P/L: 74.46 | Balance: 12420.08
# Step 12038: SELL at 86278.00 | P/L: -39.18 | Balance: 12380.90
# Step 12048: SELL at 86931.00 | P/L: 74.22 | Balance: 12455.12
# Step 12054: SELL at 87403.00 | P/L: 41.18 | Balance: 12496.30
# Step 12067: SELL at 86984.00 | P/L: -30.95 | Balance: 12465.34
# Step 12074: SELL at 86955.00 | P/L: -10.60 | Balance: 12454.74
# Step 12076: SELL at 87137.00 | P/L: 6.72 | Balance: 12461.46
# Step 12079: SELL at 87131.00 | P/L: -10.00 | Balance: 12451.46
# Step 12082: SELL at 87064.00 | P/L: -11.86 | Balance: 12439.60
# Step 12085: SELL at 87065.00 | P/L: 0.14 | Balance: 12439.74
# Step 12089: SELL at 87520.00 | P/L: 49.66 | Balance: 12489.41
# Step 12119: SELL at 87853.00 | P/L: 61.14 | Balance: 12550.55
# Step 12124: SELL at 88083.00 | P/L: 17.55 | Balance: 12568.10
# Step 12138: SELL at 88040.00 | P/L: -18.67 | Balance: 12549.43
# Step 12142: SELL at 88053.00 | P/L: -17.08 | Balance: 12532.35
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 73            |
# |    iterations           | 93            |
# |    time_elapsed         | 162           |
# |    total_timesteps      | 11904         |
# | train/                  |               |
# |    approx_kl            | 6.6615175e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.765        |
# |    explained_variance   | -1.67e-06     |
# |    learning_rate        | 0.001         |
# |    loss                 | 644           |
# |    n_updates            | 920           |
# |    policy_gradient_loss | -0.00043      |
# |    value_loss           | 1.3e+03       |
# -------------------------------------------
# Step 12214: SELL at 87913.00 | P/L: -22.48 | Balance: 12509.86
# Step 12220: SELL at 88675.00 | P/L: 97.82 | Balance: 12607.68
# Step 12241: SELL at 89569.00 | P/L: 99.59 | Balance: 12707.28
# Step 12250: SELL at 89065.00 | P/L: -65.43 | Balance: 12641.84
# Step 12252: SELL at 89118.00 | P/L: 1.99 | Balance: 12643.83
# Step 12255: SELL at 88543.00 | P/L: -39.01 | Balance: 12604.82
# Step 12268: SELL at 88728.00 | P/L: -3.27 | Balance: 12601.56
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 73            |
# |    iterations           | 94            |
# |    time_elapsed         | 164           |
# |    total_timesteps      | 12032         |
# | train/                  |               |
# |    approx_kl            | 8.4884465e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.774        |
# |    explained_variance   | 2.29e-05      |
# |    learning_rate        | 0.001         |
# |    loss                 | 631           |
# |    n_updates            | 930           |
# |    policy_gradient_loss | -0.000589     |
# |    value_loss           | 1.27e+03      |
# -------------------------------------------
# Step 12276: SELL at 88647.00 | P/L: -25.11 | Balance: 12576.44
# Step 12280: SELL at 87072.00 | P/L: -236.95 | Balance: 12339.50
# Step 12285: SELL at 87256.00 | P/L: 19.40 | Balance: 12358.90
# Step 12317: SELL at 87461.00 | P/L: 27.47 | Balance: 12386.37
# Step 12319: SELL at 87416.00 | P/L: -12.17 | Balance: 12374.20
# Step 12335: SELL at 87587.00 | P/L: 30.02 | Balance: 12404.22
# Step 12338: SELL at 87521.00 | P/L: -8.78 | Balance: 12395.44
# Step 12349: SELL at 87686.00 | P/L: 25.21 | Balance: 12420.66
# Step 12353: SELL at 87748.00 | P/L: 1.13 | Balance: 12421.79
# Step 12358: SELL at 87678.00 | P/L: -1.98 | Balance: 12419.81
# Step 12373: SELL at 87384.00 | P/L: -4.97 | Balance: 12414.83
# Step 12390: SELL at 87457.00 | P/L: 7.95 | Balance: 12422.79
# Step 12395: SELL at 87595.00 | P/L: 11.21 | Balance: 12434.00
# Step 12399: SELL at 87608.00 | P/L: -1.28 | Balance: 12432.73
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 72            |
# |    iterations           | 95            |
# |    time_elapsed         | 166           |
# |    total_timesteps      | 12160         |
# | train/                  |               |
# |    approx_kl            | 7.2512776e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.78         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 586           |
# |    n_updates            | 940           |
# |    policy_gradient_loss | 5.38e-05      |
# |    value_loss           | 1.18e+03      |
# -------------------------------------------
# Step 12402: SELL at 87631.00 | P/L: 2.70 | Balance: 12435.42
# Step 12409: SELL at 87593.00 | P/L: 2.13 | Balance: 12437.55
# Step 12430: SELL at 87603.00 | P/L: 24.04 | Balance: 12461.59
# Step 12451: SELL at 87311.00 | P/L: -26.49 | Balance: 12435.10
# Step 12454: SELL at 87370.00 | P/L: 8.69 | Balance: 12443.79
# Step 12457: SELL at 87403.00 | P/L: -1.71 | Balance: 12442.08
# Step 12489: SELL at 87445.00 | P/L: 5.84 | Balance: 12447.92
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 72            |
# |    iterations           | 96            |
# |    time_elapsed         | 168           |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 0.00064787315 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.766        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.33e+03      |
# |    n_updates            | 950           |
# |    policy_gradient_loss | -0.00164      |
# |    value_loss           | 2.67e+03      |
# -------------------------------------------
# Step 12534: SELL at 87853.00 | P/L: 27.98 | Balance: 12475.89
# Step 12564: SELL at 87841.00 | P/L: -11.92 | Balance: 12463.97
# Step 12569: SELL at 87791.00 | P/L: -4.26 | Balance: 12459.72
# Step 12582: SELL at 87848.00 | P/L: 13.20 | Balance: 12472.92
# Step 12590: SELL at 87820.00 | P/L: -8.94 | Balance: 12463.98
# Step 12594: SELL at 87966.00 | P/L: 35.67 | Balance: 12499.65
# Step 12628: SELL at 87773.00 | P/L: -32.39 | Balance: 12467.26
# Step 12643: SELL at 88228.00 | P/L: 65.20 | Balance: 12532.46
# Step 12650: SELL at 88817.00 | P/L: 59.26 | Balance: 12591.72
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 97          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 12416       |
# | train/                  |             |
# |    approx_kl            | 0.023123939 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.847      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.001       |
# |    loss                 | 25.7        |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0124     |
# |    value_loss           | 51.4        |
# -----------------------------------------
# Step 12678: SELL at 89370.00 | P/L: 110.15 | Balance: 12701.87
# Step 12680: SELL at 89157.00 | P/L: 4.56 | Balance: 12706.43
# Step 12687: SELL at 89732.00 | P/L: 99.61 | Balance: 12806.04
# Step 12691: SELL at 89621.00 | P/L: 0.14 | Balance: 12806.19
# Step 12696: SELL at 89655.00 | P/L: 9.58 | Balance: 12815.76
# Step 12700: SELL at 89802.00 | P/L: 11.86 | Balance: 12827.62
# Step 12702: SELL at 89682.00 | P/L: 9.30 | Balance: 12836.92
# Step 12704: SELL at 89819.00 | P/L: -1.14 | Balance: 12835.78
# Step 12707: SELL at 89993.00 | P/L: 16.57 | Balance: 12852.35
# Step 12715: SELL at 90415.00 | P/L: -14.91 | Balance: 12837.44
# Step 12746: SELL at 90687.00 | P/L: 43.61 | Balance: 12881.04
# Step 12750: SELL at 91359.00 | P/L: 2.12 | Balance: 12883.16
# Step 12752: SELL at 91279.00 | P/L: -40.38 | Balance: 12842.78
# Step 12756: SELL at 91421.00 | P/L: 12.80 | Balance: 12855.58
# Step 12781: SELL at 91882.00 | P/L: 46.20 | Balance: 12901.77
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 98          |
# |    time_elapsed         | 172         |
# |    total_timesteps      | 12544       |
# | train/                  |             |
# |    approx_kl            | 0.005018225 |
# |    clip_fraction        | 0.0352      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.909      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.001       |
# |    loss                 | 417         |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.00659    |
# |    value_loss           | 840         |
# -----------------------------------------
# Step 12793: SELL at 92662.00 | P/L: 60.43 | Balance: 12962.20
# Step 12799: SELL at 92857.00 | P/L: 20.27 | Balance: 12982.48
# Step 12803: SELL at 92643.00 | P/L: -14.70 | Balance: 12967.78
# Step 12814: SELL at 93233.00 | P/L: 99.94 | Balance: 13067.71
# Step 12816: SELL at 93021.00 | P/L: -34.05 | Balance: 13033.67
# Step 12822: SELL at 93178.00 | P/L: 26.77 | Balance: 13060.44
# Step 12833: SELL at 92575.00 | P/L: -68.07 | Balance: 12992.37
# Step 12835: SELL at 92253.00 | P/L: -15.33 | Balance: 12977.04
# Step 12841: SELL at 91835.00 | P/L: -85.07 | Balance: 12891.97
# Step 12845: SELL at 92210.00 | P/L: 46.16 | Balance: 12938.13
# Step 12849: SELL at 92700.00 | P/L: 45.80 | Balance: 12983.93
# Step 12860: SELL at 92649.00 | P/L: 32.17 | Balance: 13016.10
# Step 12878: SELL at 92693.00 | P/L: -6.88 | Balance: 13009.23
# Step 12881: SELL at 92389.00 | P/L: 2.68 | Balance: 13011.90
# Step 12884: SELL at 92461.00 | P/L: -4.92 | Balance: 13006.98
# Step 12888: SELL at 92378.00 | P/L: -13.36 | Balance: 12993.62
# Step 12898: SELL at 92263.00 | P/L: -8.59 | Balance: 12985.03
# Step 12901: SELL at 92004.00 | P/L: -21.56 | Balance: 12963.47
# Step 12907: SELL at 92154.00 | P/L: 33.43 | Balance: 12996.90
# Step 12910: SELL at 92228.00 | P/L: 0.14 | Balance: 12997.04
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 99           |
# |    time_elapsed         | 174          |
# |    total_timesteps      | 12672        |
# | train/                  |              |
# |    approx_kl            | 0.0008452679 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.943       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.45e+03     |
# |    n_updates            | 980          |
# |    policy_gradient_loss | 0.00152      |
# |    value_loss           | 2.92e+03     |
# ------------------------------------------
# Step 12913: SELL at 92296.00 | P/L: 2.68 | Balance: 12999.71
# Step 12924: SELL at 92579.00 | P/L: 49.76 | Balance: 13049.47
# Step 12955: SELL at 92755.00 | P/L: 32.16 | Balance: 13081.63
# Step 12957: SELL at 92802.00 | P/L: 3.81 | Balance: 13085.43
# Step 12959: SELL at 92505.00 | P/L: -11.87 | Balance: 13073.56
# Step 12969: SELL at 93138.00 | P/L: 70.70 | Balance: 13144.27
# Step 12979: SELL at 92874.00 | P/L: -49.63 | Balance: 13094.64
# Step 12981: SELL at 92773.00 | P/L: -10.30 | Balance: 13084.34
# Step 12986: SELL at 91480.00 | P/L: -130.70 | Balance: 12953.64
# Step 12988: SELL at 91697.00 | P/L: -11.71 | Balance: 12941.93
# Step 12992: SELL at 91081.00 | P/L: -63.35 | Balance: 12878.58
# Step 12995: SELL at 91201.00 | P/L: 25.75 | Balance: 12904.34
# Step 12999: SELL at 90729.00 | P/L: -11.94 | Balance: 12892.40
# Step 13007: SELL at 90702.00 | P/L: -38.55 | Balance: 12853.85
# Step 13014: SELL at 90232.00 | P/L: -146.32 | Balance: 12707.53
# Step 13017: SELL at 90705.00 | P/L: 70.01 | Balance: 12777.54
# Step 13022: SELL at 90178.00 | P/L: -34.90 | Balance: 12742.64
# Step 13025: SELL at 91000.00 | P/L: 38.20 | Balance: 12780.84
# Step 13034: SELL at 90452.00 | P/L: -31.29 | Balance: 12749.55
# Step 13037: SELL at 90483.00 | P/L: 6.63 | Balance: 12756.18
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 71            |
# |    iterations           | 100           |
# |    time_elapsed         | 177           |
# |    total_timesteps      | 12800         |
# | train/                  |               |
# |    approx_kl            | 0.00012575183 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.95         |
# |    explained_variance   | -4.77e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 703           |
# |    n_updates            | 990           |
# |    policy_gradient_loss | -0.000399     |
# |    value_loss           | 1.41e+03      |
# -------------------------------------------
# Step 13042: SELL at 89500.00 | P/L: -118.19 | Balance: 12637.99
# Step 13054: SELL at 90759.00 | P/L: 71.42 | Balance: 12709.40
# Step 13057: SELL at 90798.00 | P/L: -36.57 | Balance: 12672.84
# Step 13067: SELL at 90606.00 | P/L: -45.99 | Balance: 12626.85
# Step 13071: SELL at 90909.00 | P/L: 30.21 | Balance: 12657.06
# Step 13078: SELL at 90997.00 | P/L: 0.83 | Balance: 12657.89
# Step 13081: SELL at 90807.00 | P/L: -28.23 | Balance: 12629.66
# Step 13085: SELL at 90688.00 | P/L: -12.38 | Balance: 12617.28
# Step 13087: SELL at 90651.00 | P/L: -5.84 | Balance: 12611.43
# Step 13094: SELL at 90065.00 | P/L: -74.47 | Balance: 12536.96
# Step 13096: SELL at 89735.00 | P/L: -34.83 | Balance: 12502.13
# Step 13105: SELL at 88928.00 | P/L: -123.33 | Balance: 12378.80
# Step 13109: SELL at 88927.00 | P/L: 35.74 | Balance: 12414.54
# Step 13113: SELL at 88685.00 | P/L: -42.55 | Balance: 12371.99
# Step 13115: SELL at 88599.00 | P/L: -44.80 | Balance: 12327.19
# Step 13118: SELL at 88286.00 | P/L: -23.41 | Balance: 12303.78
# Step 13121: SELL at 88523.00 | P/L: 51.22 | Balance: 12355.00
# Step 13139: SELL at 89400.00 | P/L: 111.14 | Balance: 12466.13
# Step 13141: SELL at 89309.00 | P/L: 18.87 | Balance: 12485.01
# Step 13145: SELL at 89221.00 | P/L: -35.44 | Balance: 12449.56
# Step 13147: SELL at 89296.00 | P/L: 28.93 | Balance: 12478.49
# Step 13158: SELL at 88629.00 | P/L: -57.74 | Balance: 12420.75
# Step 13166: SELL at 89261.00 | P/L: 99.59 | Balance: 12520.34
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 71            |
# |    iterations           | 101           |
# |    time_elapsed         | 180           |
# |    total_timesteps      | 12928         |
# | train/                  |               |
# |    approx_kl            | 7.4223615e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.943        |
# |    explained_variance   | 0             |
# ...
# ------------------------------------------
# Step 28810: SELL at 102821.00 | P/L: 0.00 | Balance: 14150.32
# Step 28887: SELL at 102988.00 | P/L: 0.00 | Balance: 14150.32
# Step 28900: SELL at 103183.00 | P/L: -1.37 | Balance: 14148.95
# Step 28911: SELL at 103061.00 | P/L: -20.84 | Balance: 14128.11
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 47            |
# |    iterations           | 224           |
# |    time_elapsed         | 605           |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 0.00094497437 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.581        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 13.2          |
# |    n_updates            | 2230          |
# |    policy_gradient_loss | -0.00186      |
# |    value_loss           | 27.3          |
# -------------------------------------------
# Step 28927: SELL at 103095.00 | P/L: -10.13 | Balance: 14117.98
# Step 28929: SELL at 103075.00 | P/L: -1.37 | Balance: 14116.61
# Step 28939: SELL at 103022.00 | P/L: -0.41 | Balance: 14116.19
# Step 28964: SELL at 103247.00 | P/L: 7.52 | Balance: 14123.72
# Step 28971: SELL at 103151.00 | P/L: 1.64 | Balance: 14125.36
# Step 29021: SELL at 103207.00 | P/L: -1.23 | Balance: 14124.13
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 47           |
# |    iterations           | 225          |
# |    time_elapsed         | 611          |
# |    total_timesteps      | 28800        |
# | train/                  |              |
# |    approx_kl            | 3.209291e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.598       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.001        |
# |    loss                 | 16           |
# |    n_updates            | 2240         |
# |    policy_gradient_loss | 0.000863     |
# |    value_loss           | 32.1         |
# ------------------------------------------
# Step 29046: SELL at 103167.00 | P/L: 0.00 | Balance: 14124.13
# Step 29052: SELL at 103174.00 | P/L: -2.60 | Balance: 14121.53
# Step 29100: SELL at 103162.00 | P/L: 3.29 | Balance: 14124.82
# Step 29110: SELL at 103081.00 | P/L: 7.13 | Balance: 14131.94
# Step 29122: SELL at 102800.00 | P/L: 12.93 | Balance: 14144.88
# Step 29130: SELL at 102712.00 | P/L: 0.00 | Balance: 14144.88
# Step 29132: SELL at 102795.00 | P/L: 0.00 | Balance: 14144.88
# Step 29137: SELL at 102823.00 | P/L: 17.49 | Balance: 14162.37
# Step 29144: SELL at 103066.00 | P/L: 0.00 | Balance: 14162.37
# Step 29155: SELL at 102754.00 | P/L: -19.27 | Balance: 14143.10
# Step 29162: SELL at 102698.00 | P/L: 2.48 | Balance: 14145.58
# Step 29164: SELL at 102639.00 | P/L: 1.10 | Balance: 14146.68
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 47           |
# |    iterations           | 226          |
# |    time_elapsed         | 615          |
# |    total_timesteps      | 28928        |
# | train/                  |              |
# |    approx_kl            | 0.0025965748 |
# |    clip_fraction        | 0.0281       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.627       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.001        |
# |    loss                 | 5.81         |
# |    n_updates            | 2250         |
# |    policy_gradient_loss | -0.0026      |
# |    value_loss           | 11.6         |
# ------------------------------------------
# Step 29172: SELL at 102783.00 | P/L: 0.00 | Balance: 14146.68
# Step 29180: SELL at 103200.00 | P/L: 13.31 | Balance: 14159.99
# Step 29192: SELL at 103308.00 | P/L: 31.73 | Balance: 14191.73
# Step 29248: SELL at 104743.00 | P/L: 2.98 | Balance: 14194.71
# Step 29259: SELL at 104827.00 | P/L: -7.98 | Balance: 14186.72
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 46           |
# |    iterations           | 227          |
# |    time_elapsed         | 619          |
# |    total_timesteps      | 29056        |
# | train/                  |              |
# |    approx_kl            | 6.843265e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.65        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.001        |
# |    loss                 | 30.7         |
# |    n_updates            | 2260         |
# |    policy_gradient_loss | -9.43e-05    |
# |    value_loss           | 62.4         |
# ------------------------------------------
# Step 29316: SELL at 106817.00 | P/L: -2.52 | Balance: 14184.20
# Step 29325: SELL at 106900.00 | P/L: 1.46 | Balance: 14185.66
# Step 29351: SELL at 107224.00 | P/L: -3.84 | Balance: 14181.82
# Step 29390: SELL at 107300.00 | P/L: -19.80 | Balance: 14162.03
# Step 29417: SELL at 107205.00 | P/L: 4.89 | Balance: 14166.92
# Step 29419: SELL at 107205.00 | P/L: 2.38 | Balance: 14169.29
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 46            |
# |    iterations           | 228           |
# |    time_elapsed         | 624           |
# |    total_timesteps      | 29184         |
# | train/                  |               |
# |    approx_kl            | 0.00013207085 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.649        |
# |    explained_variance   | -2.38e-06     |
# |    learning_rate        | 0.001         |
# |    loss                 | 47.9          |
# |    n_updates            | 2270          |
# |    policy_gradient_loss | -0.0013       |
# |    value_loss           | 97.3          |
# -------------------------------------------
# Step 29430: SELL at 107322.00 | P/L: -4.36 | Balance: 14164.94
# Step 29440: SELL at 107280.00 | P/L: 1.06 | Balance: 14166.00
# Step 29454: SELL at 107067.00 | P/L: -4.36 | Balance: 14161.63
# Step 29477: SELL at 107072.00 | P/L: 3.84 | Balance: 14165.47
# Step 29480: SELL at 107054.00 | P/L: -6.75 | Balance: 14158.72
# Step 29486: SELL at 106996.00 | P/L: -0.93 | Balance: 14157.80
# Step 29504: SELL at 107136.00 | P/L: 2.11 | Balance: 14159.91
# Step 29511: SELL at 107225.00 | P/L: 0.00 | Balance: 14159.91
# Step 29531: SELL at 107135.00 | P/L: 0.93 | Balance: 14160.84
# Step 29547: SELL at 106815.00 | P/L: -10.20 | Balance: 14150.63
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 46            |
# |    iterations           | 229           |
# |    time_elapsed         | 629           |
# |    total_timesteps      | 29312         |
# | train/                  |               |
# |    approx_kl            | 4.3273438e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.649        |
# |    explained_variance   | 3.4e-06       |
# |    learning_rate        | 0.001         |
# |    loss                 | 14.9          |
# |    n_updates            | 2280          |
# |    policy_gradient_loss | 0.000413      |
# |    value_loss           | 29.8          |
# -------------------------------------------
# Step 29559: SELL at 106802.00 | P/L: -5.56 | Balance: 14145.07
# Step 29563: SELL at 106794.00 | P/L: 3.18 | Balance: 14148.25
# Step 29580: SELL at 106652.00 | P/L: 2.39 | Balance: 14150.64
# Step 29598: SELL at 106953.00 | P/L: -1.98 | Balance: 14148.66
# Step 29617: SELL at 107160.00 | P/L: -0.13 | Balance: 14148.52
# Step 29622: SELL at 106993.00 | P/L: -2.25 | Balance: 14146.28
# Step 29637: SELL at 107057.00 | P/L: 6.87 | Balance: 14153.15
# Step 29649: SELL at 107495.00 | P/L: 4.87 | Balance: 14158.02
# Step 29669: SELL at 107352.00 | P/L: 0.00 | Balance: 14158.02
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 46            |
# |    iterations           | 230           |
# |    time_elapsed         | 633           |
# |    total_timesteps      | 29440         |
# | train/                  |               |
# |    approx_kl            | 0.00033362582 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.639        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 4.79          |
# |    n_updates            | 2290          |
# |    policy_gradient_loss | -0.00118      |
# |    value_loss           | 10.3          |
# -------------------------------------------
# Step 29681: SELL at 107210.00 | P/L: 0.00 | Balance: 14158.02
# Step 29694: SELL at 107583.00 | P/L: 10.14 | Balance: 14168.16
# Step 29715: SELL at 107538.00 | P/L: 7.12 | Balance: 14175.28
# Step 29721: SELL at 107572.00 | P/L: 41.23 | Balance: 14216.52
# Step 29731: SELL at 107963.00 | P/L: -12.63 | Balance: 14203.89
# Step 29761: SELL at 106356.00 | P/L: -1.60 | Balance: 14202.28
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 46          |
# |    iterations           | 231         |
# |    time_elapsed         | 638         |
# |    total_timesteps      | 29568       |
# | train/                  |             |
# |    approx_kl            | 0.002236058 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.602      |
# |    explained_variance   | 0.000158    |
# |    learning_rate        | 0.001       |
# |    loss                 | 3.52        |
# |    n_updates            | 2300        |
# |    policy_gradient_loss | -0.00186    |
# |    value_loss           | 7.1         |
# -----------------------------------------
# Step 29841: SELL at 106865.00 | P/L: -14.21 | Balance: 14188.08
# Step 29866: SELL at 106942.00 | P/L: 23.26 | Balance: 14211.33
# Step 29880: SELL at 107179.00 | P/L: -16.29 | Balance: 14195.04
# Step 29893: SELL at 107503.00 | P/L: 6.87 | Balance: 14201.91
# Step 29916: SELL at 107446.00 | P/L: -5.29 | Balance: 14196.63
# Step 29919: SELL at 107483.00 | P/L: -8.18 | Balance: 14188.44
# Step 29923: SELL at 107564.00 | P/L: 8.58 | Balance: 14197.02
# Step 29930: SELL at 107552.00 | P/L: -6.33 | Balance: 14190.69
# Step 29935: SELL at 107486.00 | P/L: -15.96 | Balance: 14174.73
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 46            |
# |    iterations           | 232           |
# |    time_elapsed         | 643           |
# |    total_timesteps      | 29696         |
# | train/                  |               |
# |    approx_kl            | 0.00092993304 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.559        |
# |    explained_variance   | 4.17e-07      |
# |    learning_rate        | 0.001         |
# |    loss                 | 62.2          |
# |    n_updates            | 2310          |
# |    policy_gradient_loss | -7.65e-05     |
# |    value_loss           | 126           |
# -------------------------------------------
# Step 29938: SELL at 107383.00 | P/L: 10.96 | Balance: 14185.70
# Step 29951: SELL at 107111.00 | P/L: -2.52 | Balance: 14183.18
# Step 29970: SELL at 106580.00 | P/L: -17.54 | Balance: 14165.64
# Step 29993: SELL at 106688.00 | P/L: 0.80 | Balance: 14166.43
# Step 30015: SELL at 106331.00 | P/L: -11.58 | Balance: 14154.85
# Step 30021: SELL at 106238.00 | P/L: -14.91 | Balance: 14139.94
# Step 30036: SELL at 106538.00 | P/L: 5.98 | Balance: 14145.92
# Step 30040: SELL at 106593.00 | P/L: 4.38 | Balance: 14150.30
# Step 30042: SELL at 106562.00 | P/L: 0.27 | Balance: 14150.57
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 46            |
# |    iterations           | 233           |
# |    time_elapsed         | 647           |
# |    total_timesteps      | 29824         |
# | train/                  |               |
# |    approx_kl            | 0.00035504298 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.543        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 38            |
# |    n_updates            | 2320          |
# |    policy_gradient_loss | -0.00105      |
# |    value_loss           | 76.1          |
# -------------------------------------------
# Step 30075: SELL at 106714.00 | P/L: 12.21 | Balance: 14162.78
# Step 30104: SELL at 106490.00 | P/L: -5.98 | Balance: 14156.79
# Step 30130: SELL at 106479.00 | P/L: -11.56 | Balance: 14145.24
# Step 30140: SELL at 106327.00 | P/L: -6.52 | Balance: 14138.72
# Step 30147: SELL at 106268.00 | P/L: 0.00 | Balance: 14138.72
# Step 30154: SELL at 106344.00 | P/L: -9.57 | Balance: 14129.15
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 45            |
# |    iterations           | 234           |
# |    time_elapsed         | 651           |
# |    total_timesteps      | 29952         |
# | train/                  |               |
# |    approx_kl            | 0.00042863656 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.515        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 29.7          |
# |    n_updates            | 2330          |
# |    policy_gradient_loss | -0.00125      |
# |    value_loss           | 60.8          |
# -------------------------------------------
# Step 30218: SELL at 105976.00 | P/L: -9.59 | Balance: 14119.56
# Step 30233: SELL at 105827.00 | P/L: 6.67 | Balance: 14126.24
# Step 30277: SELL at 106149.00 | P/L: -3.99 | Balance: 14122.24
# Step 30309: SELL at 101512.00 | P/L: -4.73 | Balance: 14117.52
# Step 30315: SELL at 101661.00 | P/L: 4.17 | Balance: 14121.68
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 45           |
# |    iterations           | 235          |
# |    time_elapsed         | 657          |
# |    total_timesteps      | 30080        |
# | train/                  |              |
# |    approx_kl            | 0.0010321354 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.482       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.001        |
# |    loss                 | 19.6         |
# |    n_updates            | 2340         |
# |    policy_gradient_loss | -0.00478     |
# |    value_loss           | 40.8         |
# ------------------------------------------
# Step 30329: SELL at 101413.00 | P/L: -23.08 | Balance: 14098.61
# Step 30359: SELL at 101590.00 | P/L: 3.47 | Balance: 14102.08
# Step 30382: SELL at 101704.00 | P/L: 0.00 | Balance: 14102.08
# Step 30401: SELL at 101664.00 | P/L: 4.44 | Balance: 14106.52
# Step 30427: SELL at 101692.00 | P/L: -5.82 | Balance: 14100.69
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 45          |
# |    iterations           | 236         |
# |    time_elapsed         | 661         |
# |    total_timesteps      | 30208       |
# | train/                  |             |
# |    approx_kl            | 0.005640442 |
# |    clip_fraction        | 0.0234      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.416      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.001       |
# |    loss                 | 3.53        |
# |    n_updates            | 2350        |
# |    policy_gradient_loss | -0.00495    |
# |    value_loss           | 7.34        |
# -----------------------------------------

# %% [markdown]
# ### model_4
# Learning_rate = 0.0001
#
# **Results:**
#
# iterations = 10112
#
# f_balance = 9514.59

# %%
model_4 = RecurrentPPO("MlpLstmPolicy", env, learning_rate=0.0001, verbose=1)
model_4.learn(total_timesteps=total_timesteps, callback=reward_callback)

# %% [markdown]
# ### model_5
# Learning_rate = 0.0002
#
# **Results:**
#
# iterations = 10112
#
# f_balance = 10548.18

# %%
model_5 = RecurrentPPO("MlpLstmPolicy", env, learning_rate=0.0002, verbose=1)
model_5.learn(total_timesteps=total_timesteps, callback=reward_callback)

# %% [markdown]
# ### model_6
# Learning_rate = 0.002
#
# **Results:**
#
# iterations = 10112
#
# f_balance = 10002.44

# %%
model_6 = RecurrentPPO("MlpLstmPolicy", env, learning_rate=0.002, verbose=1)
model_6.learn(total_timesteps=total_timesteps, callback=reward_callback)
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Using cpu device
# Step 241: SELL at 68339.00 | P/L: -1.76 | Balance: 9998.24
# Step 247: SELL at 68363.00 | P/L: 1.17 | Balance: 9999.41
# Step 268: SELL at 68414.00 | P/L: 5.12 | Balance: 10004.53
# Step 270: SELL at 68452.00 | P/L: 0.88 | Balance: 10005.41
# Step 278: SELL at 68420.00 | P/L: -2.19 | Balance: 10003.22
# Step 285: SELL at 68381.00 | P/L: -2.05 | Balance: 10001.17
# Step 291: SELL at 68401.00 | P/L: 2.78 | Balance: 10003.95
# Step 300: SELL at 68365.00 | P/L: -7.60 | Balance: 9996.34
# Step 313: SELL at 68358.00 | P/L: -0.58 | Balance: 9995.76
# Step 317: SELL at 68358.00 | P/L: 0.00 | Balance: 9995.76
# Step 323: SELL at 68391.00 | P/L: 4.09 | Balance: 9999.85
# Step 327: SELL at 68378.00 | P/L: 0.00 | Balance: 9999.85
# Step 333: SELL at 68376.00 | P/L: 1.17 | Balance: 10001.02
# Step 335: SELL at 68384.00 | P/L: 2.05 | Balance: 10003.07
# Step 338: SELL at 68392.00 | P/L: 0.00 | Balance: 10003.07
# Step 346: SELL at 68411.00 | P/L: 0.15 | Balance: 10003.22
# Step 359: SELL at 68399.00 | P/L: -1.75 | Balance: 10001.46
# Step 364: SELL at 68387.00 | P/L: -6.14 | Balance: 9995.32
# ----------------------------
# | time/              |     |
# |    fps             | 323 |
# |    iterations      | 1   |
# |    time_elapsed    | 0   |
# |    total_timesteps | 128 |
# ----------------------------
# Step 372: SELL at 68348.00 | P/L: -2.78 | Balance: 9992.55
# Step 383: SELL at 68380.00 | P/L: -0.44 | Balance: 9992.11
# Step 386: SELL at 68352.00 | P/L: -0.29 | Balance: 9991.82
# Step 389: SELL at 68353.00 | P/L: 0.00 | Balance: 9991.82
# Step 394: SELL at 68377.00 | P/L: 3.07 | Balance: 9994.89
# Step 398: SELL at 68377.00 | P/L: 0.00 | Balance: 9994.89
# Step 400: SELL at 68365.00 | P/L: 0.00 | Balance: 9994.89
# Step 405: SELL at 68384.00 | P/L: 2.34 | Balance: 9997.22
# Step 407: SELL at 68386.00 | P/L: 0.00 | Balance: 9997.22
# Step 411: SELL at 68386.00 | P/L: 0.00 | Balance: 9997.22
# Step 426: SELL at 68413.00 | P/L: 0.29 | Balance: 9997.52
# Step 428: SELL at 68413.00 | P/L: 0.00 | Balance: 9997.52
# Step 432: SELL at 68413.00 | P/L: 0.00 | Balance: 9997.52
# Step 446: SELL at 68443.00 | P/L: 3.07 | Balance: 10000.59
# Step 449: SELL at 68448.00 | P/L: 0.73 | Balance: 10001.32
# Step 452: SELL at 68446.00 | P/L: 0.00 | Balance: 10001.32
# Step 455: SELL at 68443.00 | P/L: -0.44 | Balance: 10000.88
# Step 458: SELL at 68447.00 | P/L: 0.00 | Balance: 10000.88
# Step 480: SELL at 68400.00 | P/L: 0.00 | Balance: 10000.88
# Step 484: SELL at 68383.00 | P/L: -2.49 | Balance: 9998.39
# Step 488: SELL at 68389.00 | P/L: 0.00 | Balance: 9998.39
# Step 491: SELL at 68379.00 | P/L: 0.15 | Balance: 9998.54
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 40          |
# |    iterations           | 2           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 256         |
# | train/                  |             |
# |    approx_kl            | 0.012984635 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -5.6e-05    |
# |    learning_rate        | 0.002       |
# |    loss                 | 4.48        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.016      |
# |    value_loss           | 9.05        |
# -----------------------------------------
# Step 499: SELL at 68376.00 | P/L: -0.44 | Balance: 9998.10
# Step 501: SELL at 68362.00 | P/L: 1.02 | Balance: 9999.12
# Step 509: SELL at 68385.00 | P/L: 3.36 | Balance: 10002.49
# Step 514: SELL at 68390.00 | P/L: 1.02 | Balance: 10003.51
# Step 522: SELL at 68429.00 | P/L: 1.90 | Balance: 10005.41
# Step 527: SELL at 68427.00 | P/L: 0.29 | Balance: 10005.70
# Step 536: SELL at 68421.00 | P/L: 0.00 | Balance: 10005.70
# Step 543: SELL at 68436.00 | P/L: 4.83 | Balance: 10010.53
# Step 545: SELL at 68440.00 | P/L: 0.00 | Balance: 10010.53
# Step 549: SELL at 68436.00 | P/L: -0.15 | Balance: 10010.39
# Step 551: SELL at 68412.00 | P/L: 0.00 | Balance: 10010.39
# Step 553: SELL at 68412.00 | P/L: 0.00 | Balance: 10010.39
# Step 561: SELL at 68439.00 | P/L: 3.95 | Balance: 10014.34
# Step 564: SELL at 68432.00 | P/L: 0.00 | Balance: 10014.34
# Step 572: SELL at 68414.00 | P/L: -2.49 | Balance: 10011.85
# Step 576: SELL at 68415.00 | P/L: 0.15 | Balance: 10011.99
# Step 583: SELL at 68377.00 | P/L: 0.00 | Balance: 10011.99
# Step 590: SELL at 68385.00 | P/L: -1.32 | Balance: 10010.68
# Step 597: SELL at 68388.00 | P/L: 0.44 | Balance: 10011.12
# Step 599: SELL at 68400.00 | P/L: -0.44 | Balance: 10010.68
# Step 604: SELL at 68393.00 | P/L: -0.44 | Balance: 10010.24
# Step 608: SELL at 68362.00 | P/L: -0.29 | Balance: 10009.95
# Step 610: SELL at 68371.00 | P/L: 1.46 | Balance: 10011.41
# Step 622: SELL at 68296.00 | P/L: 2.49 | Balance: 10013.90
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 3           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 384         |
# | train/                  |             |
# |    approx_kl            | 0.026235431 |
# |    clip_fraction        | 0.0891      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.002       |
# |    loss                 | 1.15        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0126     |
# |    value_loss           | 2.48        |
# -----------------------------------------
# Step 627: SELL at 68294.00 | P/L: -3.08 | Balance: 10010.82
# Step 630: SELL at 68295.00 | P/L: 0.15 | Balance: 10010.97
# Step 638: SELL at 68234.00 | P/L: -6.89 | Balance: 10004.08
# Step 642: SELL at 68244.00 | P/L: 4.11 | Balance: 10008.19
# Step 645: SELL at 68262.00 | P/L: 3.52 | Balance: 10011.71
# Step 651: SELL at 68314.00 | P/L: 6.75 | Balance: 10018.45
# Step 660: SELL at 68408.00 | P/L: -4.25 | Balance: 10014.21
# Step 677: SELL at 68423.00 | P/L: 4.83 | Balance: 10019.04
# Step 679: SELL at 68462.00 | P/L: 5.71 | Balance: 10024.75
# Step 689: SELL at 68630.00 | P/L: 24.75 | Balance: 10049.50
# Step 699: SELL at 68691.00 | P/L: 8.20 | Balance: 10057.70
# Step 701: SELL at 68685.00 | P/L: 0.15 | Balance: 10057.84
# Step 704: SELL at 68685.00 | P/L: -2.20 | Balance: 10055.65
# Step 710: SELL at 68660.00 | P/L: 3.22 | Balance: 10058.87
# Step 714: SELL at 68676.00 | P/L: -6.15 | Balance: 10052.72
# Step 717: SELL at 68716.00 | P/L: 3.37 | Balance: 10056.09
# Step 719: SELL at 68704.00 | P/L: -0.73 | Balance: 10055.36
# Step 723: SELL at 68680.00 | P/L: 2.93 | Balance: 10058.28
# Step 729: SELL at 68631.00 | P/L: 1.32 | Balance: 10059.60
# Step 735: SELL at 68620.00 | P/L: 4.84 | Balance: 10064.44
# Step 738: SELL at 68626.00 | P/L: 0.88 | Balance: 10065.32
# Step 743: SELL at 68544.00 | P/L: -13.20 | Balance: 10052.13
# Step 749: SELL at 68514.00 | P/L: 2.05 | Balance: 10054.18
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 4           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 512         |
# | train/                  |             |
# |    approx_kl            | 0.002024116 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.002       |
# |    loss                 | 1.84        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | 0.00131     |
# |    value_loss           | 5.33        |
# -----------------------------------------
# Step 753: SELL at 68505.00 | P/L: -4.84 | Balance: 10049.34
# Step 757: SELL at 68479.00 | P/L: -2.93 | Balance: 10046.40
# Step 760: SELL at 68366.00 | P/L: -2.06 | Balance: 10044.35
# Step 765: SELL at 68437.00 | P/L: 0.44 | Balance: 10044.79
# Step 777: SELL at 68525.00 | P/L: 10.57 | Balance: 10055.35
# Step 779: SELL at 68528.00 | P/L: 0.73 | Balance: 10056.09
# Step 783: SELL at 68517.00 | P/L: -2.79 | Balance: 10053.30
# Step 785: SELL at 68569.00 | P/L: 2.49 | Balance: 10055.79
# Step 791: SELL at 68586.00 | P/L: 4.55 | Balance: 10060.34
# Step 798: SELL at 68602.00 | P/L: 1.17 | Balance: 10061.51
# Step 801: SELL at 68580.00 | P/L: -6.30 | Balance: 10055.21
# Step 804: SELL at 68538.00 | P/L: -1.91 | Balance: 10053.30
# Step 807: SELL at 68538.00 | P/L: -4.40 | Balance: 10048.90
# Step 811: SELL at 68551.00 | P/L: 1.91 | Balance: 10050.81
# Step 820: SELL at 68586.00 | P/L: 7.19 | Balance: 10057.99
# Step 825: SELL at 68575.00 | P/L: -3.08 | Balance: 10054.92
# Step 829: SELL at 68555.00 | P/L: 0.00 | Balance: 10054.92
# Step 840: SELL at 68546.00 | P/L: -1.76 | Balance: 10053.16
# Step 844: SELL at 68547.00 | P/L: 0.15 | Balance: 10053.30
# Step 848: SELL at 68539.00 | P/L: -0.15 | Balance: 10053.16
# Step 850: SELL at 68536.00 | P/L: 0.44 | Balance: 10053.60
# Step 853: SELL at 68538.00 | P/L: 0.15 | Balance: 10053.74
# Step 861: SELL at 68504.00 | P/L: 2.35 | Balance: 10056.09
# Step 864: SELL at 68521.00 | P/L: 1.91 | Balance: 10058.00
# Step 869: SELL at 68534.00 | P/L: -0.59 | Balance: 10057.41
# Step 874: SELL at 68533.00 | P/L: 0.00 | Balance: 10057.41
# Step 878: SELL at 68522.00 | P/L: 0.59 | Balance: 10058.00
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 64          |
# |    iterations           | 5           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 640         |
# | train/                  |             |
# |    approx_kl            | 0.002025146 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.002       |
# |    loss                 | 36.2        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00455    |
# |    value_loss           | 82.4        |
# -----------------------------------------
# Step 883: SELL at 68487.00 | P/L: 0.00 | Balance: 10058.00
# Step 885: SELL at 68488.00 | P/L: 0.00 | Balance: 10058.00
# Step 889: SELL at 68483.00 | P/L: 0.15 | Balance: 10058.15
# Step 891: SELL at 68479.00 | P/L: -1.32 | Balance: 10056.82
# Step 893: SELL at 68471.00 | P/L: 0.00 | Balance: 10056.82
# Step 899: SELL at 68431.00 | P/L: 2.06 | Balance: 10058.88
# Step 909: SELL at 68477.00 | P/L: 4.11 | Balance: 10063.00
# Step 912: SELL at 68576.00 | P/L: 11.61 | Balance: 10074.60
# Step 917: SELL at 68551.00 | P/L: -0.44 | Balance: 10074.16
# Step 924: SELL at 68588.00 | P/L: 6.32 | Balance: 10080.48
# Step 935: SELL at 68592.00 | P/L: -0.15 | Balance: 10080.33
# Step 942: SELL at 68631.00 | P/L: 3.09 | Balance: 10083.42
# Step 944: SELL at 68634.00 | P/L: 0.00 | Balance: 10083.42
# Step 952: SELL at 68627.00 | P/L: -0.88 | Balance: 10082.54
# Step 957: SELL at 68629.00 | P/L: 0.44 | Balance: 10082.98
# Step 964: SELL at 68626.00 | P/L: 0.00 | Balance: 10082.98
# Step 973: SELL at 68598.00 | P/L: -2.06 | Balance: 10080.92
# Step 978: SELL at 68585.00 | P/L: -1.03 | Balance: 10079.89
# Step 984: SELL at 68540.00 | P/L: -3.53 | Balance: 10076.36
# Step 987: SELL at 68538.00 | P/L: 0.15 | Balance: 10076.51
# Step 993: SELL at 68579.00 | P/L: 5.15 | Balance: 10081.66
# Step 1003: SELL at 68542.00 | P/L: -3.23 | Balance: 10078.42
# Step 1005: SELL at 68510.00 | P/L: -1.62 | Balance: 10076.80
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 69        |
# |    iterations           | 6         |
# |    time_elapsed         | 11        |
# |    total_timesteps      | 768       |
# | train/                  |           |
# |    approx_kl            | 0.0257444 |
# |    clip_fraction        | 0.253     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.966    |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.002     |
# |    loss                 | 6.52      |
# |    n_updates            | 50        |
# |    policy_gradient_loss | -0.00363  |
# |    value_loss           | 13.1      |
# ---------------------------------------
# Step 1011: SELL at 68494.00 | P/L: -0.15 | Balance: 10076.66
# Step 1016: SELL at 68498.00 | P/L: 0.59 | Balance: 10077.25
# Step 1027: SELL at 68507.00 | P/L: 1.32 | Balance: 10078.57
# Step 1033: SELL at 68512.00 | P/L: -0.15 | Balance: 10078.42
# Step 1039: SELL at 68493.00 | P/L: -2.79 | Balance: 10075.63
# Step 1042: SELL at 68478.00 | P/L: 0.00 | Balance: 10075.63
# Step 1045: SELL at 68451.00 | P/L: -2.80 | Balance: 10072.83
# Step 1047: SELL at 68498.00 | P/L: 10.01 | Balance: 10082.84
# Step 1049: SELL at 68531.00 | P/L: 2.94 | Balance: 10085.78
# Step 1062: SELL at 68552.00 | P/L: 4.86 | Balance: 10090.64
# Step 1066: SELL at 68577.00 | P/L: 3.39 | Balance: 10094.03
# Step 1069: SELL at 68632.00 | P/L: 2.50 | Balance: 10096.53
# Step 1071: SELL at 68639.00 | P/L: 1.03 | Balance: 10097.56
# Step 1074: SELL at 68709.00 | P/L: 9.71 | Balance: 10107.27
# Step 1078: SELL at 68679.00 | P/L: -0.29 | Balance: 10106.97
# Step 1080: SELL at 68700.00 | P/L: 1.47 | Balance: 10108.44
# Step 1084: SELL at 68713.00 | P/L: 4.12 | Balance: 10112.56
# Step 1091: SELL at 68851.00 | P/L: 18.69 | Balance: 10131.25
# Step 1099: SELL at 68803.00 | P/L: -5.00 | Balance: 10126.25
# Step 1101: SELL at 68815.00 | P/L: -5.29 | Balance: 10120.95
# Step 1108: SELL at 68720.00 | P/L: -6.77 | Balance: 10114.18
# Step 1115: SELL at 68703.00 | P/L: 1.33 | Balance: 10115.51
# Step 1130: SELL at 68674.00 | P/L: -5.89 | Balance: 10109.62
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 7           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 896         |
# | train/                  |             |
# |    approx_kl            | 0.019745417 |
# |    clip_fraction        | 0.0914      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.982      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.002       |
# |    loss                 | 12.1        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00644    |
# |    value_loss           | 24.9        |
# -----------------------------------------
# Step 1138: SELL at 68685.00 | P/L: -2.94 | Balance: 10106.68
# Step 1140: SELL at 68679.00 | P/L: 0.00 | Balance: 10106.68
# Step 1142: SELL at 68687.00 | P/L: -0.29 | Balance: 10106.38
# Step 1146: SELL at 68711.00 | P/L: 2.35 | Balance: 10108.74
# Step 1150: SELL at 68696.00 | P/L: -3.24 | Balance: 10105.50
# Step 1152: SELL at 68712.00 | P/L: 5.00 | Balance: 10110.50
# Step 1156: SELL at 68762.00 | P/L: 2.21 | Balance: 10112.71
# Step 1165: SELL at 68948.00 | P/L: 29.12 | Balance: 10141.83
# Step 1169: SELL at 68684.00 | P/L: -41.62 | Balance: 10100.22
# Step 1172: SELL at 68688.00 | P/L: 8.98 | Balance: 10109.20
# Step 1176: SELL at 68867.00 | P/L: 23.84 | Balance: 10133.03
# Step 1183: SELL at 68845.00 | P/L: -7.94 | Balance: 10125.09
# Step 1186: SELL at 69056.00 | P/L: 32.06 | Balance: 10157.16
# Step 1192: SELL at 69111.00 | P/L: 2.79 | Balance: 10159.95
# Step 1196: SELL at 68999.00 | P/L: -18.96 | Balance: 10140.99
# Step 1199: SELL at 69144.00 | P/L: 6.02 | Balance: 10147.01
# Step 1201: SELL at 69118.00 | P/L: -2.05 | Balance: 10144.95
# Step 1207: SELL at 69194.00 | P/L: 8.07 | Balance: 10153.02
# Step 1210: SELL at 69304.00 | P/L: 13.50 | Balance: 10166.52
# Step 1214: SELL at 69218.00 | P/L: -20.08 | Balance: 10146.43
# Step 1217: SELL at 69132.00 | P/L: -10.12 | Balance: 10136.32
# Step 1226: SELL at 68991.00 | P/L: -12.77 | Balance: 10123.55
# Step 1229: SELL at 69017.00 | P/L: 5.28 | Balance: 10128.83
# Step 1235: SELL at 69049.00 | P/L: -3.37 | Balance: 10125.46
# Step 1239: SELL at 69117.00 | P/L: 11.59 | Balance: 10137.05
# Step 1244: SELL at 69056.00 | P/L: -3.08 | Balance: 10133.97
# Step 1247: SELL at 69100.00 | P/L: 3.81 | Balance: 10137.78
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 76           |
# |    iterations           | 8            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 1024         |
# | train/                  |              |
# |    approx_kl            | 0.0016242606 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.002        |
# |    loss                 | 32.6         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00457     |
# |    value_loss           | 68.1         |
# ------------------------------------------
# Step 1264: SELL at 69003.00 | P/L: -14.96 | Balance: 10122.82
# Step 1268: SELL at 68924.00 | P/L: -7.92 | Balance: 10114.89
# Step 1272: SELL at 68940.00 | P/L: 4.55 | Balance: 10119.44
# Step 1275: SELL at 68973.00 | P/L: 0.88 | Balance: 10120.32
# Step 1277: SELL at 68993.00 | P/L: -1.76 | Balance: 10118.56
# Step 1280: SELL at 67634.00 | P/L: -202.47 | Balance: 9916.09
# Step 1286: SELL at 67584.00 | P/L: -7.33 | Balance: 9908.76
# Step 1292: SELL at 67519.00 | P/L: -8.80 | Balance: 9899.96
# Step 1296: SELL at 67456.00 | P/L: -1.91 | Balance: 9898.05
# Step 1300: SELL at 67469.00 | P/L: -5.86 | Balance: 9892.19
# Step 1306: SELL at 67488.00 | P/L: -5.71 | Balance: 9886.48
# Step 1310: SELL at 67458.00 | P/L: -4.39 | Balance: 9882.08
# Step 1318: SELL at 67356.00 | P/L: -1.17 | Balance: 9880.91
# Step 1320: SELL at 67323.00 | P/L: -4.55 | Balance: 9876.36
# Step 1326: SELL at 67330.00 | P/L: 3.23 | Balance: 9879.59
# Step 1330: SELL at 67247.00 | P/L: -12.18 | Balance: 9867.41
# Step 1335: SELL at 67248.00 | P/L: -3.08 | Balance: 9864.33
# Step 1342: SELL at 67152.00 | P/L: 6.91 | Balance: 9871.24
# Step 1346: SELL at 67058.00 | P/L: 0.15 | Balance: 9871.39
# Step 1348: SELL at 67004.00 | P/L: 1.18 | Balance: 9872.56
# Step 1352: SELL at 66924.00 | P/L: -3.39 | Balance: 9869.17
# Step 1354: SELL at 66896.00 | P/L: -11.79 | Balance: 9857.38
# Step 1361: SELL at 67058.00 | P/L: -0.88 | Balance: 9856.50
# Step 1364: SELL at 67081.00 | P/L: -0.88 | Balance: 9855.62
# Step 1370: SELL at 66979.00 | P/L: -10.00 | Balance: 9845.62
# Step 1375: SELL at 66960.00 | P/L: -2.50 | Balance: 9843.13
# Step 1378: SELL at 66879.00 | P/L: -7.65 | Balance: 9835.48
# Step 1384: SELL at 66890.00 | P/L: -2.94 | Balance: 9832.54
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 79           |
# |    iterations           | 9            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 1152         |
# | train/                  |              |
# |    approx_kl            | 0.0026720762 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.983       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.002        |
# |    loss                 | 73.1         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00237     |
# |    value_loss           | 148          |
# ------------------------------------------
# Step 1403: SELL at 66810.00 | P/L: 2.50 | Balance: 9835.04
# Step 1405: SELL at 66824.00 | P/L: -0.44 | Balance: 9834.60
# Step 1408: SELL at 66817.00 | P/L: 0.00 | Balance: 9834.60
# Step 1411: SELL at 66768.00 | P/L: -8.83 | Balance: 9825.77
# Step 1417: SELL at 66733.00 | P/L: -11.03 | Balance: 9814.74
# Step 1426: SELL at 66756.00 | P/L: 1.76 | Balance: 9816.50
# Step 1429: SELL at 66844.00 | P/L: -1.17 | Balance: 9815.33
# Step 1433: SELL at 66864.00 | P/L: -1.47 | Balance: 9813.86
# Step 1438: SELL at 66914.00 | P/L: 9.40 | Balance: 9823.26
# Step 1445: SELL at 66866.00 | P/L: -11.30 | Balance: 9811.96
# Step 1448: SELL at 66881.00 | P/L: 0.44 | Balance: 9812.40
# Step 1451: SELL at 66846.00 | P/L: 0.00 | Balance: 9812.40
# Step 1453: SELL at 66862.00 | P/L: 0.59 | Balance: 9812.99
# Step 1456: SELL at 66894.00 | P/L: -4.25 | Balance: 9808.73
# Step 1461: SELL at 66992.00 | P/L: 1.76 | Balance: 9810.49
# Step 1465: SELL at 67037.00 | P/L: -1.32 | Balance: 9809.17
# Step 1468: SELL at 67072.00 | P/L: 4.68 | Balance: 9813.86
# Step 1476: SELL at 67112.00 | P/L: 3.51 | Balance: 9817.37
# Step 1480: SELL at 67100.00 | P/L: -7.60 | Balance: 9809.76
# Step 1483: SELL at 67092.00 | P/L: 1.32 | Balance: 9811.08
# Step 1489: SELL at 67088.00 | P/L: -2.78 | Balance: 9808.30
# Step 1494: SELL at 67160.00 | P/L: 5.26 | Balance: 9813.56
# Step 1496: SELL at 67157.00 | P/L: -2.63 | Balance: 9810.93
# Step 1498: SELL at 67126.00 | P/L: -4.82 | Balance: 9806.11
# Step 1505: SELL at 67256.00 | P/L: 13.72 | Balance: 9819.84
# Step 1508: SELL at 67272.00 | P/L: 0.29 | Balance: 9820.13
# Step 1512: SELL at 67332.00 | P/L: 9.34 | Balance: 9829.47
# Step 1516: SELL at 67312.00 | P/L: -2.92 | Balance: 9826.55
# Step 1519: SELL at 67294.00 | P/L: 0.44 | Balance: 9826.99
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 81           |
# |    iterations           | 10           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 1280         |
# | train/                  |              |
# |    approx_kl            | 0.0025998224 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.972       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.002        |
# |    loss                 | 1.53e+03     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | 0.000896     |
# |    value_loss           | 3.06e+03     |
# ------------------------------------------
# Step 1523: SELL at 67298.00 | P/L: -2.92 | Balance: 9824.07
# Step 1525: SELL at 67344.00 | P/L: 5.98 | Balance: 9830.06
# Step 1531: SELL at 67367.00 | P/L: -7.73 | Balance: 9822.33
# Step 1535: SELL at 67394.00 | P/L: 10.21 | Balance: 9832.54
# Step 1539: SELL at 67333.00 | P/L: -0.73 | Balance: 9831.81
# Step 1543: SELL at 67316.00 | P/L: 0.73 | Balance: 9832.54
# Step 1551: SELL at 67285.00 | P/L: -0.44 | Balance: 9832.10
# Step 1555: SELL at 67257.00 | P/L: -3.36 | Balance: 9828.74
# Step 1557: SELL at 67246.00 | P/L: -2.48 | Balance: 9826.26
# Step 1560: SELL at 67261.00 | P/L: 2.19 | Balance: 9828.45
# Step 1563: SELL at 67332.00 | P/L: 3.65 | Balance: 9832.10
# Step 1567: SELL at 67401.00 | P/L: 12.56 | Balance: 9844.66
# Step 1573: SELL at 67330.00 | P/L: -1.32 | Balance: 9843.35
# Step 1578: SELL at 67211.00 | P/L: -23.09 | Balance: 9820.26
# Step 1583: SELL at 67033.00 | P/L: -22.51 | Balance: 9797.75
# Step 1590: SELL at 67129.00 | P/L: 0.73 | Balance: 9798.48
# Step 1597: SELL at 67020.00 | P/L: -5.11 | Balance: 9793.37
# Step 1602: SELL at 66902.00 | P/L: -14.03 | Balance: 9779.33
# Step 1609: SELL at 66957.00 | P/L: 11.41 | Balance: 9790.74
# Step 1613: SELL at 66986.00 | P/L: 5.85 | Balance: 9796.59
# Step 1617: SELL at 66957.00 | P/L: -15.92 | Balance: 9780.67
# Step 1626: SELL at 66896.00 | P/L: -14.45 | Balance: 9766.21
# Step 1630: SELL at 66962.00 | P/L: 12.71 | Balance: 9778.92
# Step 1632: SELL at 66938.00 | P/L: -2.63 | Balance: 9776.29
# Step 1634: SELL at 66924.00 | P/L: -5.26 | Balance: 9771.03
# Step 1638: SELL at 67090.00 | P/L: 5.25 | Balance: 9776.28
# Step 1642: SELL at 67054.00 | P/L: -5.68 | Balance: 9770.60
# Step 1645: SELL at 67030.00 | P/L: -1.17 | Balance: 9769.43
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 82           |
# |    iterations           | 11           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 1408         |
# | train/                  |              |
# |    approx_kl            | 0.0013758568 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.975       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.002        |
# |    loss                 | 24           |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00164     |
# |    value_loss           | 49.1         |
# ------------------------------------------
# Step 1648: SELL at 67060.00 | P/L: 1.46 | Balance: 9770.89
# Step 1657: SELL at 66929.00 | P/L: 19.02 | Balance: 9789.90
# Step 1659: SELL at 66844.00 | P/L: -11.70 | Balance: 9778.20
# Step 1664: SELL at 66859.00 | P/L: 6.00 | Balance: 9784.20
# Step 1676: SELL at 66819.00 | P/L: -2.05 | Balance: 9782.15
# Step 1680: SELL at 66948.00 | P/L: 10.68 | Balance: 9792.83
# Step 1684: SELL at 66831.00 | P/L: -9.66 | Balance: 9783.17
# Step 1688: SELL at 67243.00 | P/L: -4.22 | Balance: 9778.95
# Step 1691: SELL at 67384.00 | P/L: 22.25 | Balance: 9801.20
# Step 1695: SELL at 67387.00 | P/L: -5.09 | Balance: 9796.12
# Step 1702: SELL at 67255.00 | P/L: -12.66 | Balance: 9783.46
# Step 1708: SELL at 67051.00 | P/L: -3.35 | Balance: 9780.11
# Step 1711: SELL at 67173.00 | P/L: 2.04 | Balance: 9782.14
# Step 1723: SELL at 67411.00 | P/L: 2.76 | Balance: 9784.90
# Step 1725: SELL at 67330.00 | P/L: -12.19 | Balance: 9772.71
# Step 1730: SELL at 67435.00 | P/L: 10.74 | Balance: 9783.45
# Step 1732: SELL at 67508.00 | P/L: -1.16 | Balance: 9782.29
# Step 1739: SELL at 67568.00 | P/L: -3.91 | Balance: 9778.38
# Step 1746: SELL at 67499.00 | P/L: -11.72 | Balance: 9766.66
# Step 1755: SELL at 67426.00 | P/L: -6.51 | Balance: 9760.15
# Step 1757: SELL at 67257.00 | P/L: -25.19 | Balance: 9734.96
# Step 1763: SELL at 67157.00 | P/L: 2.90 | Balance: 9737.86
# Step 1767: SELL at 67139.00 | P/L: -1.45 | Balance: 9736.41
# Step 1774: SELL at 67311.00 | P/L: 18.41 | Balance: 9754.82
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 82           |
# |    iterations           | 12           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 1536         |
# | train/                  |              |
# |    approx_kl            | 0.0039093713 |
# |    clip_fraction        | 0.0352       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.002        |
# |    loss                 | 87           |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00395     |
# |    value_loss           | 184          |
# ------------------------------------------
# Step 1780: SELL at 67372.00 | P/L: 11.16 | Balance: 9765.98
# Step 1782: SELL at 67395.00 | P/L: -2.46 | Balance: 9763.51
# Step 1786: SELL at 67393.00 | P/L: 3.77 | Balance: 9767.28
# Step 1791: SELL at 67250.00 | P/L: -18.12 | Balance: 9749.16
# Step 1798: SELL at 67228.00 | P/L: -9.13 | Balance: 9740.03
# Step 1805: SELL at 67158.00 | P/L: 1.60 | Balance: 9741.63
# Step 1812: SELL at 67165.00 | P/L: -3.62 | Balance: 9738.00
# Step 1815: SELL at 67148.00 | P/L: -4.06 | Balance: 9733.95
# Step 1821: SELL at 66941.00 | P/L: -28.27 | Balance: 9705.67
# Step 1833: SELL at 67056.00 | P/L: 0.00 | Balance: 9705.67
# Step 1836: SELL at 66980.00 | P/L: 0.58 | Balance: 9706.25
# Step 1839: SELL at 66941.00 | P/L: -0.87 | Balance: 9705.38
# Step 1841: SELL at 66913.00 | P/L: 0.58 | Balance: 9705.96
# Step 1845: SELL at 66947.00 | P/L: 3.92 | Balance: 9709.88
# Step 1850: SELL at 66962.00 | P/L: -3.77 | Balance: 9706.11
# Step 1856: SELL at 66911.00 | P/L: -5.51 | Balance: 9700.60
# Step 1858: SELL at 66911.00 | P/L: -1.30 | Balance: 9699.30
# Step 1863: SELL at 67006.00 | P/L: 5.79 | Balance: 9705.09
# Step 1868: SELL at 67151.00 | P/L: 16.79 | Balance: 9721.88
# Step 1874: SELL at 67151.00 | P/L: 6.23 | Balance: 9728.11
# Step 1880: SELL at 67323.00 | P/L: 24.19 | Balance: 9752.30
# Step 1886: SELL at 67271.00 | P/L: -0.29 | Balance: 9752.01
# Step 1902: SELL at 67319.00 | P/L: -1.74 | Balance: 9750.28
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 81           |
# |    iterations           | 13           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 1664         |
# | train/                  |              |
# |    approx_kl            | 0.0032981308 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.002        |
# |    loss                 | 64.4         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00347     |
# |    value_loss           | 134          |
# ------------------------------------------
# Step 1916: SELL at 67259.00 | P/L: -3.91 | Balance: 9746.36
# Step 1924: SELL at 67399.00 | P/L: 4.20 | Balance: 9750.56
# Step 1934: SELL at 67277.00 | P/L: -9.27 | Balance: 9741.29
# Step 1938: SELL at 67282.00 | P/L: -1.59 | Balance: 9739.70
# Step 1947: SELL at 67468.00 | P/L: 31.14 | Balance: 9770.84
# Step 1950: SELL at 67421.00 | P/L: 1.16 | Balance: 9772.00
# Step 1952: SELL at 67417.00 | P/L: -3.33 | Balance: 9768.66
# Step 1956: SELL at 67360.00 | P/L: -5.65 | Balance: 9763.01
# Step 1961: SELL at 67341.00 | P/L: 1.89 | Balance: 9764.90
# Step 1963: SELL at 67376.00 | P/L: 12.92 | Balance: 9777.81
# Step 1969: SELL at 67427.00 | P/L: -0.87 | Balance: 9776.94
# Step 1973: SELL at 67369.00 | P/L: -5.80 | Balance: 9771.14
# Step 1978: SELL at 67331.00 | P/L: 2.03 | Balance: 9773.17
# Step 1986: SELL at 67391.00 | P/L: -0.44 | Balance: 9772.74
# Step 1989: SELL at 67444.00 | P/L: 5.36 | Balance: 9778.10
# Step 1991: SELL at 67467.00 | P/L: 1.88 | Balance: 9779.99
# Step 1994: SELL at 67447.00 | P/L: -0.58 | Balance: 9779.41
# Step 1996: SELL at 67431.00 | P/L: 0.58 | Balance: 9779.99
# Step 2002: SELL at 67472.00 | P/L: -0.43 | Balance: 9779.55
# Step 2008: SELL at 67537.00 | P/L: 3.77 | Balance: 9783.32
# Step 2015: SELL at 67470.00 | P/L: -7.24 | Balance: 9776.07
# Step 2017: SELL at 67484.00 | P/L: 7.39 | Balance: 9783.47
# Step 2021: SELL at 67413.00 | P/L: 1.74 | Balance: 9785.21
# Step 2026: SELL at 67585.00 | P/L: 2.61 | Balance: 9787.82
# Step 2030: SELL at 67502.00 | P/L: -4.20 | Balance: 9783.61
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 79         |
# |    iterations           | 14         |
# |    time_elapsed         | 22         |
# |    total_timesteps      | 1792       |
# | train/                  |            |
# |    approx_kl            | 0.01660213 |
# |    clip_fraction        | 0.1        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.07      |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.002      |
# |    loss                 | 114        |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.00908   |
# |    value_loss           | 228        |
# ----------------------------------------
# Step 2032: SELL at 67505.00 | P/L: 2.32 | Balance: 9785.93
# Step 2039: SELL at 67397.00 | P/L: -4.06 | Balance: 9781.87
# Step 2041: SELL at 67453.00 | P/L: 4.50 | Balance: 9786.37
# Step 2044: SELL at 67524.00 | P/L: -0.14 | Balance: 9786.22
# Step 2050: SELL at 67453.00 | P/L: 0.87 | Balance: 9787.09
# Step 2054: SELL at 67468.00 | P/L: -0.87 | Balance: 9786.22
# Step 2059: SELL at 67455.00 | P/L: -2.61 | Balance: 9783.61
# Step 2061: SELL at 67446.00 | P/L: -2.18 | Balance: 9781.44
# Step 2065: SELL at 67403.00 | P/L: 2.76 | Balance: 9784.19
# Step 2069: SELL at 67409.00 | P/L: 2.90 | Balance: 9787.10
# Step 2076: SELL at 67423.00 | P/L: 0.44 | Balance: 9787.53
# Step 2088: SELL at 67495.00 | P/L: 6.38 | Balance: 9793.92
# Step 2097: SELL at 67510.00 | P/L: 0.73 | Balance: 9794.64
# Step 2108: SELL at 67380.00 | P/L: -5.23 | Balance: 9789.41
# Step 2116: SELL at 67417.00 | P/L: 2.03 | Balance: 9791.45
# Step 2124: SELL at 67378.00 | P/L: -5.52 | Balance: 9785.93
# Step 2129: SELL at 67385.00 | P/L: 0.73 | Balance: 9786.65
# Step 2134: SELL at 67409.00 | P/L: 3.05 | Balance: 9789.70
# Step 2138: SELL at 67395.00 | P/L: -0.15 | Balance: 9789.56
# Step 2146: SELL at 67403.00 | P/L: 0.00 | Balance: 9789.56
# Step 2151: SELL at 67448.00 | P/L: 0.15 | Balance: 9789.70
# Step 2156: SELL at 67486.00 | P/L: 1.74 | Balance: 9791.44
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 79           |
# |    iterations           | 15           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 1920         |
# | train/                  |              |
# |    approx_kl            | 0.0065803556 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.002        |
# |    loss                 | 29.3         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | 0.00284      |
# |    value_loss           | 60.6         |
# ------------------------------------------
# Step 2160: SELL at 67450.00 | P/L: 0.87 | Balance: 9792.31
# Step 2164: SELL at 67578.00 | P/L: 3.33 | Balance: 9795.65
# Step 2169: SELL at 67662.00 | P/L: -1.16 | Balance: 9794.49
# Step 2174: SELL at 67619.00 | P/L: -0.43 | Balance: 9794.06
# Step 2178: SELL at 67592.00 | P/L: -8.54 | Balance: 9785.51
# Step 2189: SELL at 67626.00 | P/L: 0.29 | Balance: 9785.80
# Step 2195: SELL at 67593.00 | P/L: -2.89 | Balance: 9782.91
# Step 2197: SELL at 67640.00 | P/L: 2.89 | Balance: 9785.80
# Step 2199: SELL at 67673.00 | P/L: 0.00 | Balance: 9785.80
# Step 2204: SELL at 67708.00 | P/L: 0.58 | Balance: 9786.38
# Step 2207: SELL at 67710.00 | P/L: 1.88 | Balance: 9788.26
# Step 2214: SELL at 67743.00 | P/L: 2.31 | Balance: 9790.57
# Step 2220: SELL at 67729.00 | P/L: 1.88 | Balance: 9792.45
# Step 2223: SELL at 67688.00 | P/L: -5.93 | Balance: 9786.52
# Step 2227: SELL at 67613.00 | P/L: -7.23 | Balance: 9779.29
# Step 2232: SELL at 67573.00 | P/L: -2.75 | Balance: 9776.54
# Step 2235: SELL at 67558.00 | P/L: -0.87 | Balance: 9775.68
# Step 2242: SELL at 67579.00 | P/L: 1.88 | Balance: 9777.56
# Step 2252: SELL at 67475.00 | P/L: 0.00 | Balance: 9777.56
# Step 2262: SELL at 67420.00 | P/L: -9.13 | Balance: 9768.43
# Step 2272: SELL at 67336.00 | P/L: 1.02 | Balance: 9769.44
# Step 2283: SELL at 67202.00 | P/L: -23.64 | Balance: 9745.80
# Step 2286: SELL at 67114.00 | P/L: -7.55 | Balance: 9738.26
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 79           |
# |    iterations           | 16           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0059540113 |
# |    clip_fraction        | 0.269        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.002        |
# |    loss                 | 3.16         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00952     |
# |    value_loss           | 6.36         |
# ------------------------------------------
# Step 2291: SELL at 67229.00 | P/L: -0.29 | Balance: 9737.97
# Step 2300: SELL at 67157.00 | P/L: -5.36 | Balance: 9732.61
# Step 2302: SELL at 67130.00 | P/L: -3.04 | Balance: 9729.56
# Step 2312: SELL at 67036.00 | P/L: -6.67 | Balance: 9722.89
# Step 2314: SELL at 67040.00 | P/L: 0.15 | Balance: 9723.04
# Step 2320: SELL at 67021.00 | P/L: 4.35 | Balance: 9727.39
# Step 2322: SELL at 67054.00 | P/L: 0.00 | Balance: 9727.39
# Step 2329: SELL at 67127.00 | P/L: 7.54 | Balance: 9734.93
# Step 2333: SELL at 67145.00 | P/L: -4.20 | Balance: 9730.73
# Step 2336: SELL at 67119.00 | P/L: -5.94 | Balance: 9724.79
# Step 2339: SELL at 67127.00 | P/L: 1.74 | Balance: 9726.53
# Step 2343: SELL at 67086.00 | P/L: 0.58 | Balance: 9727.11
# Step 2348: SELL at 67076.00 | P/L: -2.90 | Balance: 9724.21
# Step 2352: SELL at 67142.00 | P/L: -3.04 | Balance: 9721.17
# Step 2359: SELL at 67063.00 | P/L: 4.79 | Balance: 9725.95
# Step 2363: SELL at 66984.00 | P/L: -3.05 | Balance: 9722.91
# Step 2367: SELL at 66951.00 | P/L: -0.58 | Balance: 9722.33
# Step 2377: SELL at 66834.00 | P/L: 0.00 | Balance: 9722.33
# Step 2380: SELL at 66820.00 | P/L: 2.62 | Balance: 9724.94
# Step 2387: SELL at 66843.00 | P/L: 19.97 | Balance: 9744.92
# Step 2398: SELL at 66894.00 | P/L: 0.00 | Balance: 9744.92
# Step 2404: SELL at 66889.00 | P/L: 2.77 | Balance: 9747.69
# Step 2406: SELL at 66903.00 | P/L: 1.17 | Balance: 9748.85
# Step 2412: SELL at 66851.00 | P/L: -8.60 | Balance: 9740.26
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 80           |
# |    iterations           | 17           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 2176         |
# | train/                  |              |
# |    approx_kl            | 0.0032408396 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.002        |
# |    loss                 | 44.4         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00881     |
# |    value_loss           | 95.5         |
# ------------------------------------------
# Step 2423: SELL at 66800.00 | P/L: -3.94 | Balance: 9736.32
# Step 2438: SELL at 66801.00 | P/L: -3.50 | Balance: 9732.82
# Step 2444: SELL at 66855.00 | P/L: 3.93 | Balance: 9736.76
# Step 2451: SELL at 66804.00 | P/L: 1.17 | Balance: 9737.92
# Step 2456: SELL at 66859.00 | P/L: 0.58 | Balance: 9738.51
# Step 2459: SELL at 66891.00 | P/L: 2.77 | Balance: 9741.27
# Step 2466: SELL at 66983.00 | P/L: 14.86 | Balance: 9756.13
# Step 2474: SELL at 67002.00 | P/L: -3.35 | Balance: 9752.78
# Step 2486: SELL at 66952.00 | P/L: 1.89 | Balance: 9754.67
# Step 2493: SELL at 66869.00 | P/L: -2.33 | Balance: 9752.34
# Step 2495: SELL at 66874.00 | P/L: 0.15 | Balance: 9752.49
# Step 2498: SELL at 66919.00 | P/L: 0.00 | Balance: 9752.49
# Step 2503: SELL at 66968.00 | P/L: -0.15 | Balance: 9752.34
# Step 2505: SELL at 66950.00 | P/L: 0.44 | Balance: 9752.78
# Step 2507: SELL at 66970.00 | P/L: 2.04 | Balance: 9754.82
# Step 2513: SELL at 66924.00 | P/L: -5.68 | Balance: 9749.14
# Step 2522: SELL at 67039.00 | P/L: 0.58 | Balance: 9749.72
# Step 2525: SELL at 67033.00 | P/L: 0.73 | Balance: 9750.45
# Step 2529: SELL at 67109.00 | P/L: 5.38 | Balance: 9755.82
# Step 2532: SELL at 67209.00 | P/L: 15.99 | Balance: 9771.82
# Step 2540: SELL at 67117.00 | P/L: -5.53 | Balance: 9766.29
# Step 2542: SELL at 67174.00 | P/L: 0.00 | Balance: 9766.29
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 18          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 2304        |
# | train/                  |             |
# |    approx_kl            | 0.011497794 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | -0.000244   |
# |    learning_rate        | 0.002       |
# |    loss                 | 21          |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00582    |
# |    value_loss           | 42.2        |
# -----------------------------------------
# Step 2546: SELL at 67224.00 | P/L: 2.03 | Balance: 9768.32
# Step 2549: SELL at 67220.00 | P/L: -1.45 | Balance: 9766.87
# Step 2555: SELL at 67220.00 | P/L: -0.73 | Balance: 9766.14
# Step 2570: SELL at 67280.00 | P/L: 0.58 | Balance: 9766.72
# Step 2577: SELL at 67331.00 | P/L: 3.34 | Balance: 9770.06
# Step 2584: SELL at 67314.00 | P/L: 0.00 | Balance: 9770.06
# Step 2588: SELL at 67265.00 | P/L: -4.36 | Balance: 9765.71
# Step 2590: SELL at 67277.00 | P/L: 0.58 | Balance: 9766.29
# Step 2596: SELL at 67320.00 | P/L: 11.33 | Balance: 9777.62
# Step 2604: SELL at 67372.00 | P/L: 6.68 | Balance: 9784.30
# Step 2607: SELL at 67344.00 | P/L: -0.73 | Balance: 9783.57
# Step 2609: SELL at 67364.00 | P/L: 0.58 | Balance: 9784.15
# Step 2620: SELL at 67489.00 | P/L: 4.35 | Balance: 9788.50
# Step 2623: SELL at 67396.00 | P/L: -2.03 | Balance: 9786.47
# Step 2627: SELL at 67416.00 | P/L: -3.48 | Balance: 9782.99
# Step 2633: SELL at 67580.00 | P/L: -5.93 | Balance: 9777.05
# Step 2637: SELL at 67530.00 | P/L: -9.69 | Balance: 9767.36
# Step 2648: SELL at 67519.00 | P/L: -13.58 | Balance: 9753.78
# Step 2653: SELL at 67637.00 | P/L: 13.57 | Balance: 9767.36
# Step 2656: SELL at 67622.00 | P/L: 1.30 | Balance: 9768.66
# Step 2660: SELL at 67735.00 | P/L: 9.53 | Balance: 9778.19
# Step 2666: SELL at 67735.00 | P/L: 3.47 | Balance: 9781.65
# Step 2670: SELL at 67671.00 | P/L: 1.59 | Balance: 9783.24
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 19          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 2432        |
# | train/                  |             |
# |    approx_kl            | 0.005586272 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.961      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.002       |
# |    loss                 | 16.3        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00028    |
# |    value_loss           | 35          |
# -----------------------------------------
# Step 2681: SELL at 67768.00 | P/L: -1.88 | Balance: 9781.37
# Step 2683: SELL at 67751.00 | P/L: -0.58 | Balance: 9780.79
# Step 2689: SELL at 67601.00 | P/L: -6.94 | Balance: 9773.85
# Step 2698: SELL at 67501.00 | P/L: -5.93 | Balance: 9767.92
# Step 2712: SELL at 67624.00 | P/L: 2.60 | Balance: 9770.52
# Step 2721: SELL at 67861.00 | P/L: -1.15 | Balance: 9769.36
# Step 2723: SELL at 67804.00 | P/L: 1.01 | Balance: 9770.37
# Step 2725: SELL at 67803.00 | P/L: 11.25 | Balance: 9781.63
# Step 2728: SELL at 67796.00 | P/L: -5.34 | Balance: 9776.29
# Step 2739: SELL at 67721.00 | P/L: -1.44 | Balance: 9774.85
# Step 2741: SELL at 67634.00 | P/L: -1.45 | Balance: 9773.40
# Step 2747: SELL at 67667.00 | P/L: -2.31 | Balance: 9771.09
# Step 2750: SELL at 67806.00 | P/L: 16.89 | Balance: 9787.98
# Step 2752: SELL at 67850.00 | P/L: 8.09 | Balance: 9796.07
# Step 2757: SELL at 67812.00 | P/L: -3.32 | Balance: 9792.74
# Step 2768: SELL at 67644.00 | P/L: -0.43 | Balance: 9792.31
# Step 2784: SELL at 67824.00 | P/L: 0.43 | Balance: 9792.74
# Step 2792: SELL at 67593.00 | P/L: -9.41 | Balance: 9783.34
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 81          |
# |    iterations           | 20          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.009599406 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.905      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.002       |
# |    loss                 | 24.5        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00372    |
# |    value_loss           | 49.7        |
# -----------------------------------------
# Step 2800: SELL at 67683.00 | P/L: -0.43 | Balance: 9782.90
# Step 2802: SELL at 67646.00 | P/L: 6.95 | Balance: 9789.85
# Step 2815: SELL at 67344.00 | P/L: 2.62 | Balance: 9792.47
# Step 2823: SELL at 67490.00 | P/L: 4.65 | Balance: 9797.11
# Step 2857: SELL at 67491.00 | P/L: -12.47 | Balance: 9784.64
# Step 2863: SELL at 67465.00 | P/L: -4.49 | Balance: 9780.15
# Step 2877: SELL at 67448.00 | P/L: -1.88 | Balance: 9778.26
# Step 2881: SELL at 67569.00 | P/L: 9.13 | Balance: 9787.39
# Step 2890: SELL at 67534.00 | P/L: -3.77 | Balance: 9783.62
# Step 2903: SELL at 67732.00 | P/L: 1.44 | Balance: 9785.07
# Step 2907: SELL at 67720.00 | P/L: -5.05 | Balance: 9780.01
# Step 2909: SELL at 67711.00 | P/L: 4.48 | Balance: 9784.49
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 81          |
# |    iterations           | 21          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 2688        |
# | train/                  |             |
# |    approx_kl            | 0.014272554 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.739      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.002       |
# |    loss                 | 20.5        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -4.61e-05   |
# |    value_loss           | 41          |
# -----------------------------------------
# Step 2930: SELL at 67773.00 | P/L: 9.10 | Balance: 9793.60
# Step 2935: SELL at 67825.00 | P/L: 0.29 | Balance: 9793.89
# Step 2944: SELL at 67877.00 | P/L: -1.88 | Balance: 9792.01
# Step 2949: SELL at 67832.00 | P/L: -6.49 | Balance: 9785.52
# Step 2952: SELL at 67801.00 | P/L: -9.08 | Balance: 9776.43
# Step 2966: SELL at 67659.00 | P/L: -3.18 | Balance: 9773.26
# Step 2968: SELL at 67680.00 | P/L: 0.87 | Balance: 9774.12
# Step 2971: SELL at 67784.00 | P/L: 1.15 | Balance: 9775.28
# Step 2973: SELL at 67793.00 | P/L: -0.87 | Balance: 9774.41
# Step 2979: SELL at 67708.00 | P/L: -6.35 | Balance: 9768.06
# Step 2982: SELL at 67682.00 | P/L: -0.87 | Balance: 9767.20
# Step 2984: SELL at 67695.00 | P/L: -0.72 | Balance: 9766.48
# Step 2995: SELL at 67816.00 | P/L: 4.47 | Balance: 9770.94
# Step 2998: SELL at 67867.00 | P/L: 5.33 | Balance: 9776.27
# Step 3010: SELL at 68137.00 | P/L: 12.07 | Balance: 9788.34
# Step 3019: SELL at 68126.00 | P/L: -2.87 | Balance: 9785.47
# Step 3025: SELL at 68199.00 | P/L: -2.44 | Balance: 9783.03
# Step 3028: SELL at 68231.00 | P/L: 1.58 | Balance: 9784.61
# Step 3041: SELL at 68163.00 | P/L: -8.18 | Balance: 9776.43
# Step 3043: SELL at 68135.00 | P/L: -3.87 | Balance: 9772.56
# Step 3051: SELL at 68137.00 | P/L: -0.57 | Balance: 9771.98
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 79          |
# |    iterations           | 22          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 2816        |
# | train/                  |             |
# |    approx_kl            | 0.011213622 |
# |    clip_fraction        | 0.0836      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.79       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.002       |
# |    loss                 | 10.4        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00741    |
# |    value_loss           | 21.9        |
# -----------------------------------------
# Step 3059: SELL at 68191.00 | P/L: -6.30 | Balance: 9765.68
# Step 3081: SELL at 68126.00 | P/L: 25.29 | Balance: 9790.98
# Step 3088: SELL at 68182.00 | P/L: -1.58 | Balance: 9789.40
# Step 3105: SELL at 68218.00 | P/L: 3.88 | Balance: 9793.27
# Step 3114: SELL at 68471.00 | P/L: 9.16 | Balance: 9802.44
# Step 3123: SELL at 68653.00 | P/L: -20.94 | Balance: 9781.49
# Step 3130: SELL at 68621.00 | P/L: 10.27 | Balance: 9791.77
# Step 3136: SELL at 68413.00 | P/L: -12.44 | Balance: 9779.33
# Step 3139: SELL at 68433.00 | P/L: 9.87 | Balance: 9789.20
# Step 3141: SELL at 68385.00 | P/L: -1.86 | Balance: 9787.34
# Step 3145: SELL at 68373.00 | P/L: -6.87 | Balance: 9780.47
# Step 3156: SELL at 68282.00 | P/L: -5.01 | Balance: 9775.46
# Step 3158: SELL at 68309.00 | P/L: -2.00 | Balance: 9773.46
# Step 3168: SELL at 68471.00 | P/L: -3.28 | Balance: 9770.18
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 23          |
# |    time_elapsed         | 37          |
# ...
# |    n_updates            | 670           |
# |    policy_gradient_loss | 0.000776      |
# |    value_loss           | 62.7          |
# -------------------------------------------
# Step 8950: SELL at 69975.00 | P/L: -2.85 | Balance: 9972.28
# Step 8977: SELL at 70203.00 | P/L: -2.84 | Balance: 9969.44
# Step 9029: SELL at 69481.00 | P/L: -29.61 | Balance: 9939.83
# Step 9053: SELL at 69513.00 | P/L: 2.00 | Balance: 9941.83
# Step 9063: SELL at 69264.00 | P/L: 9.77 | Balance: 9951.60
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 63           |
# |    iterations           | 69           |
# |    time_elapsed         | 139          |
# |    total_timesteps      | 8832         |
# | train/                  |              |
# |    approx_kl            | 0.0010891417 |
# |    clip_fraction        | 0.00625      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.316       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.002        |
# |    loss                 | 7.19         |
# |    n_updates            | 680          |
# |    policy_gradient_loss | -0.00152     |
# |    value_loss           | 14.5         |
# ------------------------------------------
# Step 9074: SELL at 69552.00 | P/L: -3.00 | Balance: 9948.60
# Step 9085: SELL at 69488.00 | P/L: -4.15 | Balance: 9944.45
# Step 9088: SELL at 69562.00 | P/L: -4.00 | Balance: 9940.44
# Step 9104: SELL at 69343.00 | P/L: 4.02 | Balance: 9944.46
# Step 9107: SELL at 69323.00 | P/L: -2.44 | Balance: 9942.02
# Step 9119: SELL at 69544.00 | P/L: 2.43 | Balance: 9944.45
# Step 9122: SELL at 69527.00 | P/L: -1.86 | Balance: 9942.59
# Step 9145: SELL at 69370.00 | P/L: -8.31 | Balance: 9934.29
# Step 9169: SELL at 69084.00 | P/L: -2.88 | Balance: 9931.41
# Step 9174: SELL at 69086.00 | P/L: -13.35 | Balance: 9918.06
# Step 9177: SELL at 68946.00 | P/L: -12.93 | Balance: 9905.13
# Step 9194: SELL at 69358.00 | P/L: -7.56 | Balance: 9897.57
# Step 9198: SELL at 69367.00 | P/L: -0.29 | Balance: 9897.28
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 62            |
# |    iterations           | 70            |
# |    time_elapsed         | 142           |
# |    total_timesteps      | 8960          |
# | train/                  |               |
# |    approx_kl            | 4.8525166e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.347        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.002         |
# |    loss                 | 30.6          |
# |    n_updates            | 690           |
# |    policy_gradient_loss | 0.0001        |
# |    value_loss           | 63.2          |
# -------------------------------------------
# Step 9208: SELL at 69324.00 | P/L: -4.85 | Balance: 9892.43
# Step 9217: SELL at 69568.00 | P/L: 7.12 | Balance: 9899.55
# Step 9263: SELL at 69443.00 | P/L: -18.21 | Balance: 9881.33
# Step 9267: SELL at 69477.00 | P/L: 3.70 | Balance: 9885.03
# Step 9284: SELL at 74877.00 | P/L: -0.40 | Balance: 9884.64
# Step 9288: SELL at 74811.00 | P/L: -1.32 | Balance: 9883.31
# Step 9290: SELL at 74895.00 | P/L: 6.07 | Balance: 9889.39
# Step 9304: SELL at 74961.00 | P/L: 0.53 | Balance: 9889.92
# Step 9313: SELL at 74873.00 | P/L: 0.26 | Balance: 9890.18
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 62           |
# |    iterations           | 71           |
# |    time_elapsed         | 146          |
# |    total_timesteps      | 9088         |
# | train/                  |              |
# |    approx_kl            | 6.279349e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.355       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.002        |
# |    loss                 | 34.9         |
# |    n_updates            | 700          |
# |    policy_gradient_loss | -0.000353    |
# |    value_loss           | 75.9         |
# ------------------------------------------
# Step 9332: SELL at 75088.00 | P/L: 5.27 | Balance: 9895.45
# Step 9336: SELL at 75166.00 | P/L: 8.96 | Balance: 9904.41
# Step 9371: SELL at 75103.00 | P/L: 7.92 | Balance: 9912.33
# Step 9405: SELL at 75073.00 | P/L: -0.13 | Balance: 9912.20
# Step 9431: SELL at 74972.00 | P/L: 11.38 | Balance: 9923.58
# Step 9453: SELL at 75008.00 | P/L: 0.66 | Balance: 9924.24
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 62           |
# |    iterations           | 72           |
# |    time_elapsed         | 148          |
# |    total_timesteps      | 9216         |
# | train/                  |              |
# |    approx_kl            | 0.0024369978 |
# |    clip_fraction        | 0.0258       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.382       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.002        |
# |    loss                 | 8.79         |
# |    n_updates            | 710          |
# |    policy_gradient_loss | -0.00293     |
# |    value_loss           | 17.9         |
# ------------------------------------------
# Step 9461: SELL at 74911.00 | P/L: -7.15 | Balance: 9917.10
# Step 9490: SELL at 74963.00 | P/L: 0.00 | Balance: 9917.10
# Step 9502: SELL at 75062.00 | P/L: 4.36 | Balance: 9921.46
# Step 9504: SELL at 75015.00 | P/L: 2.51 | Balance: 9923.97
# Step 9570: SELL at 74924.00 | P/L: -4.77 | Balance: 9919.20
# Step 9578: SELL at 74961.00 | P/L: -5.42 | Balance: 9913.78
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 73          |
# |    time_elapsed         | 150         |
# |    total_timesteps      | 9344        |
# | train/                  |             |
# |    approx_kl            | 0.005444973 |
# |    clip_fraction        | 0.0453      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.321      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.002       |
# |    loss                 | 10.9        |
# |    n_updates            | 720         |
# |    policy_gradient_loss | 0.0217      |
# |    value_loss           | 22.3        |
# -----------------------------------------
# Step 9596: SELL at 74982.00 | P/L: 3.97 | Balance: 9917.75
# Step 9599: SELL at 74986.00 | P/L: -3.83 | Balance: 9913.92
# Step 9602: SELL at 75047.00 | P/L: 3.30 | Balance: 9917.22
# Step 9640: SELL at 74918.00 | P/L: 4.37 | Balance: 9921.59
# Step 9662: SELL at 74654.00 | P/L: -7.30 | Balance: 9914.29
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 61            |
# |    iterations           | 74            |
# |    time_elapsed         | 152           |
# |    total_timesteps      | 9472          |
# | train/                  |               |
# |    approx_kl            | 0.00056691375 |
# |    clip_fraction        | 0.00313       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.293        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.002         |
# |    loss                 | 4.93          |
# |    n_updates            | 730           |
# |    policy_gradient_loss | -0.00133      |
# |    value_loss           | 10.1          |
# -------------------------------------------
# Step 9720: SELL at 74909.00 | P/L: 0.13 | Balance: 9914.42
# Step 9744: SELL at 74959.00 | P/L: 12.05 | Balance: 9926.47
# Step 9771: SELL at 75370.00 | P/L: -6.71 | Balance: 9919.76
# Step 9776: SELL at 75461.00 | P/L: -1.84 | Balance: 9917.92
# Step 9787: SELL at 75932.00 | P/L: 14.91 | Balance: 9932.83
# Step 9805: SELL at 75887.00 | P/L: -6.80 | Balance: 9926.03
# Step 9815: SELL at 75775.00 | P/L: 4.32 | Balance: 9930.35
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 61           |
# |    iterations           | 75           |
# |    time_elapsed         | 155          |
# |    total_timesteps      | 9600         |
# | train/                  |              |
# |    approx_kl            | 0.0016575474 |
# |    clip_fraction        | 0.0328       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.261       |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.002        |
# |    loss                 | 2.3          |
# |    n_updates            | 740          |
# |    policy_gradient_loss | -0.000122    |
# |    value_loss           | 4.62         |
# ------------------------------------------
# Step 9844: SELL at 75872.00 | P/L: 6.29 | Balance: 9936.64
# Step 9846: SELL at 75804.00 | P/L: -7.99 | Balance: 9928.65
# Step 9854: SELL at 76007.00 | P/L: 3.53 | Balance: 9932.18
# Step 9858: SELL at 75980.00 | P/L: -1.44 | Balance: 9930.74
# Step 9871: SELL at 76148.00 | P/L: 7.83 | Balance: 9938.57
# Step 9896: SELL at 76444.00 | P/L: -6.11 | Balance: 9932.46
# Step 9899: SELL at 76244.00 | P/L: 1.17 | Balance: 9933.64
# Step 9901: SELL at 76287.00 | P/L: -3.12 | Balance: 9930.51
# Step 9907: SELL at 76409.00 | P/L: 8.85 | Balance: 9939.36
# Step 9910: SELL at 76351.00 | P/L: -9.10 | Balance: 9930.25
# Step 9916: SELL at 76500.00 | P/L: 5.58 | Balance: 9935.84
# Step 9919: SELL at 76445.00 | P/L: 3.38 | Balance: 9939.22
# Step 9940: SELL at 76333.00 | P/L: -0.52 | Balance: 9938.70
# Step 9960: SELL at 76553.00 | P/L: -3.76 | Balance: 9934.93
# Step 9967: SELL at 76604.00 | P/L: -6.22 | Balance: 9928.71
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 76          |
# |    time_elapsed         | 157         |
# |    total_timesteps      | 9728        |
# | train/                  |             |
# |    approx_kl            | 0.042423807 |
# |    clip_fraction        | 0.0625      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.449      |
# |    explained_variance   | -6.68e-06   |
# |    learning_rate        | 0.002       |
# |    loss                 | 9.73        |
# |    n_updates            | 750         |
# |    policy_gradient_loss | 0.00775     |
# |    value_loss           | 20.6        |
# -----------------------------------------
# Step 9974: SELL at 76632.00 | P/L: 4.54 | Balance: 9933.25
# Step 9987: SELL at 76444.00 | P/L: 3.12 | Balance: 9936.37
# Step 10000: SELL at 76154.00 | P/L: 6.66 | Balance: 9943.03
# Step 10004: SELL at 76185.00 | P/L: 3.66 | Balance: 9946.68
# Step 10006: SELL at 76439.00 | P/L: 26.75 | Balance: 9973.43
# Step 10010: SELL at 76371.00 | P/L: 5.23 | Balance: 9978.66
# Step 10019: SELL at 76263.00 | P/L: -16.46 | Balance: 9962.20
# Step 10027: SELL at 76310.00 | P/L: 3.26 | Balance: 9965.46
# Step 10032: SELL at 76434.00 | P/L: -2.09 | Balance: 9963.38
# Step 10046: SELL at 76597.00 | P/L: -6.63 | Balance: 9956.75
# Step 10048: SELL at 76635.00 | P/L: 1.82 | Balance: 9958.57
# Step 10050: SELL at 76725.00 | P/L: 7.66 | Balance: 9966.23
# Step 10054: SELL at 76781.00 | P/L: 7.40 | Balance: 9973.64
# Step 10059: SELL at 76897.00 | P/L: 2.98 | Balance: 9976.62
# Step 10077: SELL at 76667.00 | P/L: 0.91 | Balance: 9977.53
# Step 10082: SELL at 76593.00 | P/L: 2.22 | Balance: 9979.75
# Step 10088: SELL at 76535.00 | P/L: 0.26 | Balance: 9980.01
# Step 10090: SELL at 76562.00 | P/L: 5.61 | Balance: 9985.61
# Step 10095: SELL at 76684.00 | P/L: 9.51 | Balance: 9995.13
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 60         |
# |    iterations           | 77         |
# |    time_elapsed         | 161        |
# |    total_timesteps      | 9856       |
# | train/                  |            |
# |    approx_kl            | 0.00947305 |
# |    clip_fraction        | 0.0984     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.615     |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.002      |
# |    loss                 | 7.51       |
# |    n_updates            | 760        |
# |    policy_gradient_loss | -0.00677   |
# |    value_loss           | 15.1       |
# ----------------------------------------
# Step 10097: SELL at 76707.00 | P/L: -3.00 | Balance: 9992.13
# Step 10105: SELL at 76741.00 | P/L: 8.08 | Balance: 10000.21
# Step 10131: SELL at 76343.00 | P/L: -0.13 | Balance: 10000.08
# Step 10135: SELL at 76178.00 | P/L: -1.31 | Balance: 9998.77
# Step 10137: SELL at 76243.00 | P/L: 12.47 | Balance: 10011.24
# Step 10140: SELL at 76225.00 | P/L: 8.28 | Balance: 10019.52
# Step 10152: SELL at 76123.00 | P/L: 4.08 | Balance: 10023.61
# Step 10158: SELL at 75969.00 | P/L: -1.06 | Balance: 10022.55
# Step 10163: SELL at 75979.00 | P/L: -2.77 | Balance: 10019.78
# Step 10166: SELL at 75860.00 | P/L: -13.19 | Balance: 10006.59
# Step 10174: SELL at 75696.00 | P/L: -5.95 | Balance: 10000.65
# Step 10204: SELL at 75888.00 | P/L: 6.20 | Balance: 10006.84
# Step 10209: SELL at 75826.00 | P/L: 1.19 | Balance: 10008.03
# Step 10215: SELL at 75833.00 | P/L: -3.30 | Balance: 10004.73
# Step 10218: SELL at 75889.00 | P/L: 6.07 | Balance: 10010.80
# Step 10220: SELL at 75999.00 | P/L: 10.28 | Balance: 10021.09
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 60         |
# |    iterations           | 78         |
# |    time_elapsed         | 164        |
# |    total_timesteps      | 9984       |
# | train/                  |            |
# |    approx_kl            | 0.00300703 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.604     |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.002      |
# |    loss                 | 60.6       |
# |    n_updates            | 770        |
# |    policy_gradient_loss | 0.00629    |
# |    value_loss           | 124        |
# ----------------------------------------
# Step 10225: SELL at 75801.00 | P/L: -7.53 | Balance: 10013.56
# Step 10228: SELL at 75807.00 | P/L: -11.87 | Balance: 10001.68
# Step 10230: SELL at 75825.00 | P/L: -1.71 | Balance: 9999.97
# Step 10234: SELL at 75947.00 | P/L: 8.96 | Balance: 10008.93
# Step 10242: SELL at 75955.00 | P/L: 6.59 | Balance: 10015.52
# Step 10249: SELL at 75916.00 | P/L: -0.13 | Balance: 10015.39
# Step 10262: SELL at 76034.00 | P/L: -0.66 | Balance: 10014.73
# Step 10282: SELL at 76445.00 | P/L: 0.13 | Balance: 10014.86
# Step 10288: SELL at 76449.00 | P/L: 1.31 | Balance: 10016.17
# Step 10293: SELL at 76487.00 | P/L: -1.96 | Balance: 10014.21
# Step 10299: SELL at 76488.00 | P/L: -3.01 | Balance: 10011.20
# Step 10302: SELL at 76453.00 | P/L: -1.05 | Balance: 10010.15
# Step 10305: SELL at 76475.00 | P/L: 1.83 | Balance: 10011.98
# Step 10308: SELL at 76487.00 | P/L: 1.05 | Balance: 10013.03
# Step 10310: SELL at 76480.00 | P/L: 1.05 | Balance: 10014.08
# Step 10322: SELL at 76543.00 | P/L: -3.01 | Balance: 10011.07
# Step 10324: SELL at 76516.00 | P/L: -5.10 | Balance: 10005.97
# Step 10329: SELL at 76483.00 | P/L: -3.27 | Balance: 10002.70
# Step 10337: SELL at 76596.00 | P/L: 0.00 | Balance: 10002.70
# Step 10339: SELL at 76607.00 | P/L: 0.91 | Balance: 10003.61
# Step 10350: SELL at 76610.00 | P/L: -1.18 | Balance: 10002.44
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 60           |
# |    iterations           | 79           |
# |    time_elapsed         | 166          |
# |    total_timesteps      | 10112        |
# | train/                  |              |
# |    approx_kl            | 0.0005995799 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.578       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.002        |
# |    loss                 | 29.7         |
# |    n_updates            | 780          |
# |    policy_gradient_loss | -0.000947    |
# |    value_loss           | 61.4         |
# ------------------------------------------

# %% [markdown]
# ## Best Working was model_3 so full data on it with 1000 iteration

# %%
total_timesteps=6000000
model_3_1 = RecurrentPPO("MlpLstmPolicy", env, learning_rate=0.001, verbose=1)
model_3_1.learn(total_timesteps=total_timesteps, callback=reward_callback)
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
# |    time_elapsed         | 24686     |
# |    total_timesteps      | 1489152   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 8.58e-08  |
# |    n_updates            | 116330    |
# |    policy_gradient_loss | 2.34e-08  |
# |    value_loss           | 2.85e-08  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11635     |
# |    time_elapsed         | 24688     |
# |    total_timesteps      | 1489280   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.001     |
# |    loss                 | 8.76e-08  |
# |    n_updates            | 116340    |
# |    policy_gradient_loss | 9.22e-09  |
# |    value_loss           | 3.9e-08   |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11636     |
# |    time_elapsed         | 24690     |
# |    total_timesteps      | 1489408   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | -9.63e-08 |
# |    n_updates            | 116350    |
# |    policy_gradient_loss | -2.71e-08 |
# |    value_loss           | 9.21e-08  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11637     |
# |    time_elapsed         | 24692     |
# |    total_timesteps      | 1489536   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 2.42e-08  |
# |    n_updates            | 116360    |
# |    policy_gradient_loss | 4.19e-08  |
# |    value_loss           | 2.24e-07  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11638     |
# |    time_elapsed         | 24694     |
# |    total_timesteps      | 1489664   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 2.87e-07  |
# |    n_updates            | 116370    |
# |    policy_gradient_loss | -1.29e-08 |
# |    value_loss           | 5.75e-07  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11639     |
# |    time_elapsed         | 24697     |
# |    total_timesteps      | 1489792   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.12e-06  |
# |    n_updates            | 116380    |
# |    policy_gradient_loss | 1.46e-07  |
# |    value_loss           | 1.52e-06  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11640     |
# |    time_elapsed         | 24699     |
# |    total_timesteps      | 1489920   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.84e-06  |
# |    n_updates            | 116390    |
# |    policy_gradient_loss | 1.14e-07  |
# |    value_loss           | 3.85e-06  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11641     |
# |    time_elapsed         | 24701     |
# |    total_timesteps      | 1490048   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 3.44e-06  |
# |    n_updates            | 116400    |
# |    policy_gradient_loss | 5.23e-08  |
# |    value_loss           | 7.58e-06  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11642     |
# |    time_elapsed         | 24702     |
# |    total_timesteps      | 1490176   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.91e-06  |
# |    n_updates            | 116410    |
# |    policy_gradient_loss | 2.31e-08  |
# |    value_loss           | 6.99e-06  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11643     |
# |    time_elapsed         | 24704     |
# |    total_timesteps      | 1490304   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 3.86e-07  |
# |    n_updates            | 116420    |
# |    policy_gradient_loss | 4.62e-08  |
# |    value_loss           | 1.33e-06  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11644     |
# |    time_elapsed         | 24706     |
# |    total_timesteps      | 1490432   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 2.03e-07  |
# |    n_updates            | 116430    |
# |    policy_gradient_loss | 1.62e-07  |
# |    value_loss           | 8.09e-08  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11645     |
# |    time_elapsed         | 24709     |
# |    total_timesteps      | 1490560   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | -2.28e-07 |
# |    n_updates            | 116440    |
# |    policy_gradient_loss | -5.02e-08 |
# |    value_loss           | 2.19e-08  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11646     |
# |    time_elapsed         | 24712     |
# |    total_timesteps      | 1490688   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 8.22e-08  |
# |    n_updates            | 116450    |
# |    policy_gradient_loss | -8.21e-08 |
# |    value_loss           | 4.56e-08  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11647     |
# |    time_elapsed         | 24713     |
# |    total_timesteps      | 1490816   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.71e-09  |
# |    n_updates            | 116460    |
# |    policy_gradient_loss | 6.76e-08  |
# |    value_loss           | 1.16e-07  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11648     |
# |    time_elapsed         | 24715     |
# |    total_timesteps      | 1490944   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.1e-08   |
# |    n_updates            | 116470    |
# |    policy_gradient_loss | -1.1e-07  |
# |    value_loss           | 3.04e-07  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11649     |
# |    time_elapsed         | 24717     |
# |    total_timesteps      | 1491072   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.001     |
# |    loss                 | 3.56e-07  |
# |    n_updates            | 116480    |
# |    policy_gradient_loss | 7.64e-09  |
# |    value_loss           | 8.29e-07  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11650     |
# |    time_elapsed         | 24719     |
# |    total_timesteps      | 1491200   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.26e-06  |
# |    n_updates            | 116490    |
# |    policy_gradient_loss | 4.43e-08  |
# |    value_loss           | 2.26e-06  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11651     |
# |    time_elapsed         | 24721     |
# |    total_timesteps      | 1491328   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.001     |
# |    loss                 | 3.02e-06  |
# |    n_updates            | 116500    |
# |    policy_gradient_loss | 6.28e-08  |
# |    value_loss           | 5.56e-06  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11652     |
# |    time_elapsed         | 24723     |
# |    total_timesteps      | 1491456   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 3.07e-06  |
# |    n_updates            | 116510    |
# |    policy_gradient_loss | 4.64e-08  |
# |    value_loss           | 8.99e-06  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11653     |
# |    time_elapsed         | 24726     |
# |    total_timesteps      | 1491584   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 9.14e-07  |
# |    n_updates            | 116520    |
# |    policy_gradient_loss | 3.49e-08  |
# |    value_loss           | 4.53e-06  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11654     |
# |    time_elapsed         | 24728     |
# |    total_timesteps      | 1491712   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | -1.96e-07 |
# |    n_updates            | 116530    |
# |    policy_gradient_loss | -4.48e-08 |
# |    value_loss           | 3.25e-07  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11655     |
# |    time_elapsed         | 24730     |
# |    total_timesteps      | 1491840   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.001     |
# |    loss                 | -7.8e-08  |
# |    n_updates            | 116540    |
# |    policy_gradient_loss | 1.91e-07  |
# |    value_loss           | 2.77e-08  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11656     |
# |    time_elapsed         | 24732     |
# |    total_timesteps      | 1491968   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 5.96e-08  |
# |    learning_rate        | 0.001     |
# |    loss                 | -8.38e-08 |
# |    n_updates            | 116550    |
# |    policy_gradient_loss | -1.2e-08  |
# |    value_loss           | 3.97e-08  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11657     |
# |    time_elapsed         | 24734     |
# |    total_timesteps      | 1492096   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | -1.84e-07 |
# |    n_updates            | 116560    |
# |    policy_gradient_loss | 8.12e-08  |
# |    value_loss           | 8.87e-08  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11658     |
# |    time_elapsed         | 24736     |
# |    total_timesteps      | 1492224   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.26e-07  |
# |    n_updates            | 116570    |
# |    policy_gradient_loss | 3.25e-08  |
# |    value_loss           | 2.07e-07  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11659     |
# |    time_elapsed         | 24738     |
# |    total_timesteps      | 1492352   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 2.71e-07  |
# |    n_updates            | 116580    |
# |    policy_gradient_loss | 4.61e-08  |
# |    value_loss           | 5.14e-07  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11660     |
# |    time_elapsed         | 24741     |
# |    total_timesteps      | 1492480   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.12e-06  |
# |    n_updates            | 116590    |
# |    policy_gradient_loss | 2.31e-07  |
# |    value_loss           | 1.34e-06  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11661     |
# |    time_elapsed         | 24743     |
# |    total_timesteps      | 1492608   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.87e-06  |
# |    n_updates            | 116600    |
# |    policy_gradient_loss | -2.12e-07 |
# |    value_loss           | 3.38e-06  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11662     |
# |    time_elapsed         | 24745     |
# |    total_timesteps      | 1492736   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.001     |
# |    loss                 | 3.02e-06  |
# |    n_updates            | 116610    |
# |    policy_gradient_loss | -2.18e-07 |
# |    value_loss           | 6.97e-06  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11663     |
# |    time_elapsed         | 24747     |
# |    total_timesteps      | 1492864   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.62e-06  |
# |    n_updates            | 116620    |
# |    policy_gradient_loss | -4.43e-08 |
# |    value_loss           | 7.53e-06  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11664     |
# |    time_elapsed         | 24749     |
# |    total_timesteps      | 1492992   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 5.96e-08  |
# |    learning_rate        | 0.001     |
# |    loss                 | 5.42e-07  |
# |    n_updates            | 116630    |
# |    policy_gradient_loss | -7.01e-08 |
# |    value_loss           | 1.94e-06  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11665     |
# |    time_elapsed         | 24751     |
# |    total_timesteps      | 1493120   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 2.59e-07  |
# |    n_updates            | 116640    |
# |    policy_gradient_loss | 1.53e-07  |
# |    value_loss           | 1.36e-07  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11666     |
# |    time_elapsed         | 24753     |
# |    total_timesteps      | 1493248   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | -1.93e-07 |
# |    n_updates            | 116650    |
# |    policy_gradient_loss | -5.05e-08 |
# |    value_loss           | 2.3e-08   |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11667     |
# |    time_elapsed         | 24755     |
# |    total_timesteps      | 1493376   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.001     |
# |    loss                 | -3.66e-07 |
# |    n_updates            | 116660    |
# |    policy_gradient_loss | 3.72e-08  |
# |    value_loss           | 3.92e-08  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11668     |
# |    time_elapsed         | 24758     |
# |    total_timesteps      | 1493504   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 1.79e-07  |
# |    learning_rate        | 0.001     |
# |    loss                 | -4.22e-08 |
# |    n_updates            | 116670    |
# |    policy_gradient_loss | -1.22e-07 |
# |    value_loss           | 1.03e-07  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11669     |
# |    time_elapsed         | 24760     |
# |    total_timesteps      | 1493632   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 5.96e-08  |
# |    learning_rate        | 0.001     |
# |    loss                 | -9.55e-09 |
# |    n_updates            | 116680    |
# |    policy_gradient_loss | -3.95e-08 |
# |    value_loss           | 2.77e-07  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11670     |
# |    time_elapsed         | 24762     |
# |    total_timesteps      | 1493760   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 5.95e-07  |
# |    n_updates            | 116690    |
# |    policy_gradient_loss | 5.82e-08  |
# |    value_loss           | 7.62e-07  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11671     |
# |    time_elapsed         | 24764     |
# |    total_timesteps      | 1493888   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.17e-06  |
# |    n_updates            | 116700    |
# |    policy_gradient_loss | 6.44e-08  |
# |    value_loss           | 2.1e-06   |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11672     |
# |    time_elapsed         | 24766     |
# |    total_timesteps      | 1494016   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 2.98e-06  |
# |    n_updates            | 116710    |
# |    policy_gradient_loss | 1.54e-07  |
# |    value_loss           | 5.26e-06  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11673     |
# |    time_elapsed         | 24768     |
# |    total_timesteps      | 1494144   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 3.22e-06  |
# |    n_updates            | 116720    |
# |    policy_gradient_loss | 6.98e-09  |
# |    value_loss           | 8.93e-06  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11674     |
# |    time_elapsed         | 24770     |
# |    total_timesteps      | 1494272   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.25e-06  |
# |    n_updates            | 116730    |
# |    policy_gradient_loss | 5.44e-08  |
# |    value_loss           | 5.06e-06  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11675     |
# |    time_elapsed         | 24773     |
# |    total_timesteps      | 1494400   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 6.31e-09  |
# |    n_updates            | 116740    |
# |    policy_gradient_loss | -2.33e-08 |
# |    value_loss           | 4.08e-07  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11676     |
# |    time_elapsed         | 24775     |
# |    total_timesteps      | 1494528   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | -1.21e-07 |
# |    n_updates            | 116750    |
# |    policy_gradient_loss | -9e-08    |
# |    value_loss           | 2.83e-08  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11677     |
# |    time_elapsed         | 24777     |
# |    total_timesteps      | 1494656   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 5.96e-08  |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.69e-07  |
# |    n_updates            | 116760    |
# |    policy_gradient_loss | 9.04e-08  |
# |    value_loss           | 3.53e-08  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11678     |
# |    time_elapsed         | 24779     |
# |    total_timesteps      | 1494784   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.22e-07  |
# |    n_updates            | 116770    |
# |    policy_gradient_loss | 5.79e-08  |
# |    value_loss           | 7.85e-08  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11679     |
# |    time_elapsed         | 24780     |
# |    total_timesteps      | 1494912   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.15e-07  |
# |    n_updates            | 116780    |
# |    policy_gradient_loss | 3.14e-08  |
# |    value_loss           | 1.81e-07  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11680     |
# |    time_elapsed         | 24782     |
# |    total_timesteps      | 1495040   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 3.15e-07  |
# |    n_updates            | 116790    |
# |    policy_gradient_loss | -6.79e-08 |
# |    value_loss           | 4.49e-07  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11681     |
# |    time_elapsed         | 24785     |
# |    total_timesteps      | 1495168   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.001     |
# |    loss                 | 3.83e-07  |
# |    n_updates            | 116800    |
# |    policy_gradient_loss | 6.17e-08  |
# |    value_loss           | 1.17e-06  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11682     |
# |    time_elapsed         | 24788     |
# |    total_timesteps      | 1495296   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.49e-06  |
# |    n_updates            | 116810    |
# |    policy_gradient_loss | -6.86e-08 |
# |    value_loss           | 3e-06     |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11683     |
# |    time_elapsed         | 24790     |
# |    total_timesteps      | 1495424   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 3.14e-06  |
# |    n_updates            | 116820    |
# |    policy_gradient_loss | -1.4e-07  |
# |    value_loss           | 6.54e-06  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11684     |
# |    time_elapsed         | 24791     |
# |    total_timesteps      | 1495552   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 2.57e-06  |
# |    n_updates            | 116830    |
# |    policy_gradient_loss | 1.01e-07  |
# |    value_loss           | 8.09e-06  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11685     |
# |    time_elapsed         | 24793     |
# |    total_timesteps      | 1495680   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 4.14e-07  |
# |    n_updates            | 116840    |
# |    policy_gradient_loss | 2.23e-08  |
# |    value_loss           | 2.6e-06   |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11686     |
# |    time_elapsed         | 24795     |
# |    total_timesteps      | 1495808   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.001     |
# |    loss                 | -5.18e-07 |
# |    n_updates            | 116850    |
# |    policy_gradient_loss | 1.27e-07  |
# |    value_loss           | 1.83e-07  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11687     |
# |    time_elapsed         | 24797     |
# |    total_timesteps      | 1495936   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 5.96e-08  |
# |    learning_rate        | 0.001     |
# |    loss                 | 5.48e-08  |
# |    n_updates            | 116860    |
# |    policy_gradient_loss | -2.65e-09 |
# |    value_loss           | 2.54e-08  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11688     |
# |    time_elapsed         | 24799     |
# |    total_timesteps      | 1496064   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 6.3e-08   |
# |    n_updates            | 116870    |
# |    policy_gradient_loss | 6.57e-09  |
# |    value_loss           | 3.96e-08  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11689     |
# |    time_elapsed         | 24802     |
# |    total_timesteps      | 1496192   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | -2.56e-07 |
# |    n_updates            | 116880    |
# |    policy_gradient_loss | -7.73e-08 |
# |    value_loss           | 1.01e-07  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11690     |
# |    time_elapsed         | 24804     |
# |    total_timesteps      | 1496320   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.67e-07  |
# |    n_updates            | 116890    |
# |    policy_gradient_loss | 1.2e-08   |
# |    value_loss           | 2.63e-07  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11691     |
# |    time_elapsed         | 24806     |
# |    total_timesteps      | 1496448   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 7.53e-07  |
# |    n_updates            | 116900    |
# |    policy_gradient_loss | 5.35e-08  |
# |    value_loss           | 7.09e-07  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11692     |
# |    time_elapsed         | 24808     |
# |    total_timesteps      | 1496576   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.42e-06  |
# |    n_updates            | 116910    |
# |    policy_gradient_loss | -3.21e-08 |
# |    value_loss           | 1.93e-06  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11693     |
# |    time_elapsed         | 24810     |
# |    total_timesteps      | 1496704   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 2.54e-06  |
# |    n_updates            | 116920    |
# |    policy_gradient_loss | -3.35e-08 |
# |    value_loss           | 4.82e-06  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11694     |
# |    time_elapsed         | 24812     |
# |    total_timesteps      | 1496832   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 3.27e-06  |
# |    n_updates            | 116930    |
# |    policy_gradient_loss | -1.08e-07 |
# |    value_loss           | 8.54e-06  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11695     |
# |    time_elapsed         | 24813     |
# |    total_timesteps      | 1496960   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.001     |
# |    loss                 | 9.27e-07  |
# |    n_updates            | 116940    |
# |    policy_gradient_loss | -1.3e-07  |
# |    value_loss           | 5.62e-06  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11696     |
# |    time_elapsed         | 24816     |
# |    total_timesteps      | 1497088   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.89e-07  |
# |    n_updates            | 116950    |
# |    policy_gradient_loss | 1.2e-07   |
# |    value_loss           | 5.99e-07  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11697     |
# |    time_elapsed         | 24819     |
# |    total_timesteps      | 1497216   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | -9.43e-08 |
# |    n_updates            | 116960    |
# |    policy_gradient_loss | 8.2e-08   |
# |    value_loss           | 3.6e-08   |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11698     |
# |    time_elapsed         | 24821     |
# |    total_timesteps      | 1497344   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | -5.67e-08 |
# |    n_updates            | 116970    |
# |    policy_gradient_loss | 7.06e-08  |
# |    value_loss           | 2.8e-08   |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11699     |
# |    time_elapsed         | 24823     |
# |    total_timesteps      | 1497472   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.63e-07  |
# |    n_updates            | 116980    |
# |    policy_gradient_loss | 1.27e-07  |
# |    value_loss           | 6.47e-08  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11700     |
# |    time_elapsed         | 24825     |
# |    total_timesteps      | 1497600   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.25e-07  |
# ...
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11896     |
# |    time_elapsed         | 25234     |
# |    total_timesteps      | 1522688   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 4.66e-07  |
# |    n_updates            | 118950    |
# |    policy_gradient_loss | 1.36e-07  |
# |    value_loss           | 1.56e-06  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11897     |
# |    time_elapsed         | 25236     |
# |    total_timesteps      | 1522816   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 3.11e-08  |
# |    n_updates            | 118960    |
# |    policy_gradient_loss | -1.14e-08 |
# |    value_loss           | 8.1e-08   |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11898     |
# |    time_elapsed         | 25238     |
# |    total_timesteps      | 1522944   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 5.96e-08  |
# |    learning_rate        | 0.001     |
# |    loss                 | -1.73e-07 |
# |    n_updates            | 118970    |
# |    policy_gradient_loss | -2.19e-08 |
# |    value_loss           | 2.39e-08  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11899     |
# |    time_elapsed         | 25240     |
# |    total_timesteps      | 1523072   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.001     |
# |    loss                 | -1.73e-07 |
# |    n_updates            | 118980    |
# |    policy_gradient_loss | -1.14e-08 |
# |    value_loss           | 5.07e-08  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11900     |
# |    time_elapsed         | 25242     |
# |    total_timesteps      | 1523200   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.001     |
# |    loss                 | 8.22e-08  |
# |    n_updates            | 118990    |
# |    policy_gradient_loss | 5.77e-08  |
# |    value_loss           | 1.21e-07  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11901     |
# |    time_elapsed         | 25243     |
# |    total_timesteps      | 1523328   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.83e-07  |
# |    n_updates            | 119000    |
# |    policy_gradient_loss | 6.99e-08  |
# |    value_loss           | 3.03e-07  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11902     |
# |    time_elapsed         | 25246     |
# |    total_timesteps      | 1523456   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.001     |
# |    loss                 | 6.74e-07  |
# |    n_updates            | 119010    |
# |    policy_gradient_loss | -3.18e-08 |
# |    value_loss           | 7.99e-07  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11903     |
# |    time_elapsed         | 25249     |
# |    total_timesteps      | 1523584   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.23e-06  |
# |    n_updates            | 119020    |
# |    policy_gradient_loss | 2.24e-08  |
# |    value_loss           | 2.12e-06  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11904     |
# |    time_elapsed         | 25251     |
# |    total_timesteps      | 1523712   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.001     |
# |    loss                 | 2.93e-06  |
# |    n_updates            | 119030    |
# |    policy_gradient_loss | 1.74e-08  |
# |    value_loss           | 5.15e-06  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11905     |
# |    time_elapsed         | 25252     |
# |    total_timesteps      | 1523840   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 3.15e-06  |
# |    n_updates            | 119040    |
# |    policy_gradient_loss | -1.17e-07 |
# |    value_loss           | 8.54e-06  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11906     |
# |    time_elapsed         | 25254     |
# |    total_timesteps      | 1523968   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.17e-06  |
# |    n_updates            | 119050    |
# |    policy_gradient_loss | 5.16e-08  |
# |    value_loss           | 4.96e-06  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11907     |
# |    time_elapsed         | 25256     |
# |    total_timesteps      | 1524096   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.75e-07  |
# |    n_updates            | 119060    |
# |    policy_gradient_loss | 1.56e-07  |
# |    value_loss           | 4.87e-07  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11908     |
# |    time_elapsed         | 25258     |
# |    total_timesteps      | 1524224   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.001     |
# |    loss                 | 2.42e-07  |
# |    n_updates            | 119070    |
# |    policy_gradient_loss | 1.26e-07  |
# |    value_loss           | 3.48e-08  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11909     |
# |    time_elapsed         | 25260     |
# |    total_timesteps      | 1524352   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | -2.62e-07 |
# |    n_updates            | 119080    |
# |    policy_gradient_loss | -1.65e-07 |
# |    value_loss           | 3.19e-08  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11910     |
# |    time_elapsed         | 25263     |
# |    total_timesteps      | 1524480   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.19e-07  |
# |    n_updates            | 119090    |
# |    policy_gradient_loss | 8.56e-08  |
# |    value_loss           | 7.69e-08  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 11911     |
# |    time_elapsed         | 25265     |
# |    total_timesteps      | 1524608   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.73e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 2.11e-07  |
# |    n_updates            | 119100    |
# |    policy_gradient_loss | 2.48e-07  |
# |    value_loss           | 1.89e-07  |
# ---------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-74-4f8557770b1a> in <cell line: 0>()
#       1 total_timesteps=6000000
#       2 model_3_1 = RecurrentPPO("MlpLstmPolicy", env, learning_rate=0.001, verbose=1)
# ----> 3 model_3_1.learn(total_timesteps=total_timesteps, callback=reward_callback)
#
# /usr/local/lib/python3.11/dist-packages/sb3_contrib/ppo_recurrent/ppo_recurrent.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     448         progress_bar: bool = False,
#     449     ) -> SelfRecurrentPPO:
# --> 450         return super().learn(
#     451             total_timesteps=total_timesteps,
#     452             callback=callback,
#
# /usr/local/lib/python3.11/dist-packages/stable_baselines3/common/on_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     321
#     322         while self.num_timesteps < total_timesteps:
# --> 323             continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     324
#     325             if not continue_training:
#
# /usr/local/lib/python3.11/dist-packages/sb3_contrib/ppo_recurrent/ppo_recurrent.py in collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     250                 clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
#     251
# --> 252             new_obs, rewards, dones, infos = env.step(clipped_actions)
#     253
#     254             self.num_timesteps += env.num_envs
#
# /usr/local/lib/python3.11/dist-packages/stable_baselines3/common/vec_env/base_vec_env.py in step(self, actions)
#     205         """
#     206         self.step_async(actions)
# --> 207         return self.step_wait()
#     208
#     209     def get_images(self) -> Sequence[Optional[np.ndarray]]:
#
# /usr/local/lib/python3.11/dist-packages/stable_baselines3/common/vec_env/dummy_vec_env.py in step_wait(self)
#      71                 obs, self.reset_infos[env_idx] = self.envs[env_idx].reset()
#      72             self._save_obs(env_idx, obs)
# ---> 73         return (self._obs_from_buf(), np.copy(self.buf_rews), np.copy(self.buf_dones), deepcopy(self.buf_infos))
#      74
#      75     def reset(self) -> VecEnvObs:
#
# /usr/lib/python3.11/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# /usr/lib/python3.11/copy.py in _deepcopy_list(x, memo, deepcopy)
#     204     append = y.append
#     205     for a in x:
# --> 206         append(deepcopy(a, memo))
#     207     return y
#     208 d[list] = _deepcopy_list
#
# /usr/lib/python3.11/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# /usr/lib/python3.11/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     229     memo[id(x)] = y
#     230     for key, value in x.items():
# --> 231         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232     return y
#     233 d[dict] = _deepcopy_dict
#
# /usr/lib/python3.11/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# /usr/lib/python3.11/copy.py in _deepcopy_list(x, memo, deepcopy)
#     204     append = y.append
#     205     for a in x:
# --> 206         append(deepcopy(a, memo))
#     207     return y
#     208 d[list] = _deepcopy_list
#
# /usr/lib/python3.11/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# /usr/lib/python3.11/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     229     memo[id(x)] = y
#     230     for key, value in x.items():
# --> 231         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232     return y
#     233 d[dict] = _deepcopy_dict
#
# /usr/lib/python3.11/copy.py in deepcopy(x, memo, _nil)
#     142     cls = type(x)
#     143
# --> 144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
#     146         y = copier(x, memo)
#
# KeyboardInterrupt:

# %%
policy_weights = model_3_1.policy.state_dict()
print(policy_weights)  # Shows all learned weights
# Out:
# OrderedDict([('mlp_extractor.policy_net.0.weight', tensor([[-0.0522, -0.0210, -0.1242,  ...,  0.0295,  0.1829, -0.1071],
#         [-0.0611, -0.0062, -0.0015,  ...,  0.0932, -0.0064, -0.0006],
#         [-0.0340, -0.0194,  0.0259,  ...,  0.0182, -0.0402, -0.0313],
#         ...,
#         [-0.0562,  0.0524,  0.1106,  ..., -0.1356,  0.0185,  0.0288],
#         [-0.1174,  0.1792,  0.0752,  ...,  0.0624, -0.0950, -0.0780],
#         [-0.0207, -0.1055,  0.1071,  ..., -0.1061, -0.0473, -0.1924]])), ('mlp_extractor.policy_net.0.bias', tensor([-0.0248,  0.0411, -0.0399,  0.0098,  0.0306,  0.0315, -0.0338, -0.0236,
#          0.0308, -0.0286, -0.0269, -0.0296, -0.0367,  0.0317, -0.0285,  0.0227,
#         -0.0306, -0.0343, -0.0305,  0.0290,  0.0426,  0.0396, -0.0184,  0.0208,
#          0.0284,  0.0227, -0.0263, -0.0241, -0.0130,  0.0287,  0.0309, -0.0311,
#          0.0204,  0.0401, -0.0035,  0.0251,  0.0330, -0.0104, -0.0434,  0.0310,
#          0.0233,  0.0233,  0.0338, -0.0128, -0.0320,  0.0348, -0.0103, -0.0208,
#         -0.0267,  0.0097,  0.0416, -0.0108, -0.0268,  0.0142, -0.0280, -0.0260,
#         -0.0364, -0.0415,  0.0307,  0.0256,  0.0235,  0.0201,  0.0287, -0.0215])), ('mlp_extractor.policy_net.2.weight', tensor([[ 0.4688, -0.0017,  0.0490,  ..., -0.1507, -0.2040, -0.3625],
#         [-0.0879, -0.0335,  0.3673,  ..., -0.0079, -0.1755, -0.1692],
#         [-0.2785,  0.0222,  0.1342,  ...,  0.0313,  0.0943, -0.2871],
#         ...,
#         [-0.2671,  0.0111, -0.1286,  ...,  0.0617, -0.1642,  0.3224],
#         [-0.1524,  0.1880,  0.2855,  ..., -0.1506, -0.2094, -0.0494],
#         [ 0.2328, -0.1883, -0.1747,  ...,  0.3234, -0.0073, -0.0509]])), ('mlp_extractor.policy_net.2.bias', tensor([-0.0484, -0.0398,  0.0379,  0.0407, -0.0219,  0.0410,  0.0432, -0.0282,
#         -0.0359,  0.0380, -0.0366, -0.0252, -0.0310,  0.0323, -0.0310, -0.0334,
#         -0.0287,  0.0436,  0.0402, -0.0301, -0.0374,  0.0414,  0.0471, -0.0345,
#          0.0342, -0.0455, -0.0200, -0.0425, -0.0144, -0.0497, -0.0386,  0.0522,
#         -0.0282, -0.0227, -0.0418,  0.0225,  0.0364, -0.0346,  0.0294, -0.0436,
#         -0.0311,  0.0325,  0.0416, -0.0364, -0.0443, -0.0439,  0.0432, -0.0352,
#         -0.0307, -0.0300,  0.0503,  0.0359,  0.0312, -0.0232, -0.0222, -0.0518,
#          0.0446,  0.0397,  0.0440, -0.0219,  0.0416, -0.0327, -0.0183,  0.0287])), ('mlp_extractor.value_net.0.weight', tensor([[ 0.1471, -0.2989,  0.1568,  ..., -0.0783, -0.0742,  0.1066],
#         [ 0.0079, -0.0340,  0.0379,  ...,  0.0517, -0.0102, -0.1269],
#         [-0.0914, -0.0568, -0.0822,  ...,  0.1929,  0.0103, -0.0172],
#         ...,
#         [-0.0383,  0.1791, -0.1787,  ...,  0.0582,  0.0127,  0.0784],
#         [-0.0767, -0.1564, -0.2080,  ..., -0.0625,  0.1449, -0.0492],
#         [ 0.0540, -0.1730, -0.0587,  ...,  0.0054, -0.0053,  0.1008]])), ('mlp_extractor.value_net.0.bias', tensor([-0.0417, -0.0275, -0.0147, -0.0180, -0.0267, -0.0337, -0.0241, -0.0030,
#         -0.0413,  0.0193, -0.0109, -0.0413,  0.0375, -0.0359,  0.0246,  0.0173,
#          0.0014, -0.0491, -0.0653, -0.0404,  0.0401,  0.0372,  0.0159,  0.0157,
#          0.0310,  0.0532, -0.0356, -0.0526,  0.0148,  0.0389, -0.0350,  0.0162,
#         -0.0576,  0.0579,  0.0172, -0.0498,  0.0423, -0.0498,  0.0310, -0.0384,
#          0.0660,  0.0125, -0.0298, -0.0294, -0.0477,  0.0462, -0.0375, -0.0003,
#          0.0441,  0.0444, -0.0536,  0.0429,  0.0445, -0.0231, -0.0332,  0.0306,
#          0.0461, -0.0433,  0.0511, -0.0483, -0.0298,  0.0457, -0.0496,  0.0407])), ('mlp_extractor.value_net.2.weight', tensor([[-0.0258, -0.2012, -0.0476,  ..., -0.2696,  0.0819,  0.0618],
#         [-0.2400, -0.0093, -0.0515,  ...,  0.1831,  0.3568, -0.1985],
#         [-0.0525,  0.2292, -0.1681,  ..., -0.0385, -0.0911, -0.3615],
#         ...,
#         [-0.0769,  0.3860, -0.1057,  ..., -0.2953, -0.1662, -0.1310],
#         [ 0.0040,  0.3384,  0.1916,  ..., -0.0152,  0.1240,  0.0073],
#         [ 0.0689,  0.3296,  0.0228,  ...,  0.1826,  0.3089,  0.0510]])), ('mlp_extractor.value_net.2.bias', tensor([ 0.0134, -0.0671, -0.0812, -0.0540, -0.0903,  0.0106,  0.0213, -0.0468,
#         -0.0095, -0.0705, -0.0940,  0.0168,  0.0476,  0.0181, -0.0290,  0.0351,
#         -0.0609, -0.0178,  0.0505, -0.0019, -0.0819,  0.0154, -0.0282, -0.0327,
#          0.0606,  0.0195, -0.0104, -0.0452, -0.0399, -0.0123, -0.0118,  0.0194,
#         -0.0728,  0.0615,  0.0783,  0.0580,  0.0419,  0.0695, -0.0331, -0.0690,
#          0.0322,  0.0864, -0.0585, -0.0536, -0.0827, -0.0911,  0.0921,  0.0629,
#          0.0399,  0.0699,  0.0198, -0.0134, -0.0679, -0.0154,  0.0042, -0.0780,
#          0.0831, -0.0015,  0.0741,  0.0560,  0.0285,  0.0045, -0.0279, -0.0156])), ('action_net.weight', tensor([[ 0.0934,  0.0910, -0.1010, -0.0820,  0.0961, -0.1189, -0.0989,  0.1036,
#           0.1050, -0.0945,  0.1031,  0.1153,  0.1105, -0.0993,  0.1055,  0.1097,
#           0.1012, -0.0939, -0.0968,  0.0945,  0.0949, -0.0975, -0.0884,  0.0935,
#          -0.0927,  0.0910,  0.1018,  0.0927,  0.0903,  0.0848,  0.0902, -0.0978,
#           0.1043,  0.1026,  0.0922, -0.0941, -0.1424,  0.0983, -0.0937,  0.0773,
#           0.1042, -0.1246, -0.0920,  0.0844,  0.0956,  0.1013, -0.0932,  0.0890,
#           0.1154,  0.0921, -0.0878, -0.0914, -0.0955,  0.0924,  0.0967,  0.0849,
#          -0.0925, -0.0932, -0.0927,  0.0949, -0.0841,  0.0907,  0.1011, -0.0998],
#         [ 0.0626,  0.0578, -0.0704, -0.0660,  0.0577, -0.0959, -0.0708,  0.0616,
#           0.0694, -0.0608,  0.0687,  0.0633,  0.0651, -0.0766,  0.0926,  0.0717,
#           0.0693, -0.0616, -0.0695,  0.0675,  0.0597, -0.0627, -0.0662,  0.0567,
#          -0.0680,  0.0661,  0.0641,  0.0717,  0.0808,  0.0599,  0.0671, -0.0644,
#           0.0629,  0.0607,  0.0667, -0.0572, -0.0710,  0.0633, -0.0521,  0.0548,
#           0.0671, -0.1119, -0.0663,  0.0523,  0.0690,  0.0705, -0.0693,  0.0746,
#           0.0553,  0.0578, -0.0651, -0.0628, -0.0635,  0.0579,  0.0764,  0.0593,
#          -0.0633, -0.0523, -0.0636,  0.0584, -0.0609,  0.0698,  0.0655, -0.0639],
#         [-0.1554, -0.1554,  0.1574,  0.1661, -0.1521,  0.1843,  0.1592, -0.1586,
#          -0.1604,  0.1610, -0.1606, -0.1788, -0.1615,  0.1822, -0.1886, -0.1605,
#          -0.1628,  0.1568,  0.1559, -0.1591, -0.1571,  0.1583,  0.1530, -0.1520,
#           0.1586, -0.1490, -0.1602, -0.1545, -0.1756, -0.1658, -0.1559,  0.1531,
#          -0.1593, -0.1687, -0.1562,  0.1577,  0.1896, -0.1570,  0.1521, -0.1560,
#          -0.1702,  0.2073,  0.1459, -0.1467, -0.1555, -0.1598,  0.1629, -0.1616,
#          -0.1803, -0.1525,  0.1577,  0.1615,  0.1629, -0.1525, -0.1830, -0.1697,
#           0.1582,  0.1517,  0.1520, -0.1528,  0.1466, -0.1775, -0.1632,  0.1599]])), ('action_net.bias', tensor([-0.0908, -0.0494,  0.1467])), ('value_net.weight', tensor([[ 3.4188e-05, -4.3516e-02, -1.2036e-01,  2.1627e-01, -1.6331e-01,
#          -6.1657e-05, -4.8510e-02,  3.6131e-02, -1.1617e-04,  9.6162e-02,
#          -1.7905e-01, -1.2400e-01, -1.4140e-01, -8.6302e-02,  4.6602e-02,
#          -5.5184e-02, -5.6944e-02,  3.9558e-02, -7.2481e-02,  3.7730e-02,
#          -4.7968e-02, -4.3395e-02, -2.5694e-04, -2.7391e-04,  6.7905e-02,
#          -4.2420e-02,  2.1404e-04,  2.7938e-01,  3.2022e-01,  3.1799e-02,
#           1.0164e-01, -9.9383e-02, -1.2329e-01,  6.5744e-02,  8.8536e-02,
#           7.6928e-02, -5.8227e-02,  1.1359e-01, -5.3998e-02,  8.8752e-02,
#          -2.9458e-02,  2.7678e-01,  7.9567e-02, -5.1471e-05, -1.0248e-01,
#           8.9706e-02,  1.1044e-01,  8.4142e-02, -5.1693e-02,  2.5005e-01,
#           8.0466e-05, -1.5019e-04, -1.7438e-01,  2.7652e-05, -6.7237e-05,
#          -8.7480e-02,  1.5748e-01, -5.6838e-05, -7.8579e-02,  9.3220e-02,
#          -4.5882e-02,  1.5867e-04,  1.0568e-01, -7.3606e-06]])), ('value_net.bias', tensor([0.0048])), ('lstm_actor.weight_ih_l0', tensor([[ 0.0252, -0.0577, -0.0143],
#         [-0.0453,  0.0612,  0.0261],
#         [-0.0458, -0.0170, -0.0612],
#         ...,
#         [ 0.0188,  0.0400,  0.0088],
#         [ 0.0170,  0.0450,  0.0054],
#         [ 0.0418,  0.0512,  0.0283]])), ('lstm_actor.weight_hh_l0', tensor([[ 5.9746e-02,  4.3410e-02, -4.8588e-02,  ..., -4.7243e-02,
#          -1.4891e-02, -3.5019e-02],
#         [-2.4117e-02, -7.1936e-04,  2.3416e-02,  ..., -1.5851e-02,
#          -5.4448e-03,  5.7637e-03],
#         [-4.2973e-02, -3.8181e-02,  2.8953e-05,  ..., -6.1892e-03,
#           1.7001e-02, -3.0029e-03],
#         ...,
#         [-1.5311e-02,  4.8754e-02, -2.7130e-02,  ..., -2.6203e-02,
#           5.5691e-02,  5.9129e-02],
#         [ 5.1933e-02,  2.4624e-02,  1.2623e-02,  ...,  4.6817e-02,
#          -4.3465e-02,  9.9936e-03],
#         [-1.7765e-02, -2.0573e-02,  5.6111e-02,  ...,  4.1408e-02,
#          -6.6270e-03, -7.5090e-03]])), ('lstm_actor.bias_ih_l0', tensor([-0.0101, -0.0389, -0.0203,  ...,  0.0345, -0.0188, -0.0099])), ('lstm_actor.bias_hh_l0', tensor([ 0.0225,  0.0293, -0.0450,  ...,  0.0524,  0.0163, -0.0374])), ('lstm_critic.weight_ih_l0', tensor([[ 0.0239, -0.0177, -0.0620],
#         [ 0.0368, -0.0392,  0.0570],
#         [-0.0407, -0.0011, -0.0146],
#         ...,
#         [-0.0547,  0.0151,  0.0060],
#         [-0.0236, -0.0376,  0.0519],
#         [ 0.0384,  0.0012,  0.0586]])), ('lstm_critic.weight_hh_l0', tensor([[ 0.0563,  0.0407, -0.0063,  ..., -0.0376,  0.0179,  0.0576],
#         [ 0.0126, -0.0595,  0.0538,  ..., -0.0430,  0.0424, -0.0032],
#         [ 0.0495, -0.0359, -0.0114,  ...,  0.0573,  0.0160,  0.0357],
#         ...,
#         [-0.0428, -0.0339,  0.0335,  ..., -0.0367,  0.0473, -0.0161],
#         [-0.0552, -0.0158, -0.0223,  ..., -0.0463,  0.0427,  0.0075],
#         [-0.0280, -0.0258, -0.0284,  ...,  0.0261, -0.0382,  0.0295]])), ('lstm_critic.bias_ih_l0', tensor([ 0.0431, -0.0433, -0.0251,  ..., -0.0414, -0.0239,  0.0588])), ('lstm_critic.bias_hh_l0', tensor([ 0.0015, -0.0173, -0.0567,  ...,  0.0387,  0.0097,  0.0088]))])

# %% [markdown]
# ## Predicting

# %%
def predict_actions(model, env, steps=100):
    obs = env.reset()
    actions = []
    for _ in range(steps):
        action, _ = model.predict(obs, deterministic=True)
        actions.append(action)
        obs, reward, done, _ = env.step(action)
        if done:
            break
    return actions

# %% [markdown]
# ### model_2

# %%
predicted_actions = predict_actions(model_2, env, steps=100)
print("Predicted actions over 100 steps:", predicted_actions)
# Out:
# Predicted actions over 100 steps: [array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2])]
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### model_3

# %%
predicted_actions = predict_actions(model_3, env, steps=100)
print("Predicted actions over 100 steps:", predicted_actions)
# Out:
# Predicted actions over 100 steps: [array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2])]
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### model_4

# %%
predicted_actions = predict_actions(model_4, env, steps=100)
print("Predicted actions over 100 steps:", predicted_actions)
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Predicted actions over 100 steps: [array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1])]

# %% [markdown]
# ### model_5

# %%
predicted_actions = predict_actions(model_5, env, steps=100)
print("Predicted actions over 100 steps:", predicted_actions)
# Out:
# Predicted actions over 100 steps: [array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2])]
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### model_6

# %%
predicted_actions = predict_actions(model_6, env, steps=100)
print("Predicted actions over 100 steps:", predicted_actions)
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Predicted actions over 100 steps: [array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2])]

# %% [markdown]
# ## Predict with best model

# %%
predicted_actions = predict_actions(model_3_1, env, steps=100)
print("Predicted actions over 100 steps:", predicted_actions)
# Out:
# Predicted actions over 100 steps: [array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2]), array([2])]
